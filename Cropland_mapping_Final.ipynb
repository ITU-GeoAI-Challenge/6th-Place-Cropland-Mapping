# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/zindi/crop
# Out:
# /content/drive/MyDrive/Colab Notebooks/zindi/crop

# %% [markdown]
# ### <font color="brown"> Import packages

# %%
# !pip -qq install catboost
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 2.3 MB/s eta 0:00:00

# %%
import numpy as np
import pandas as pd
import random
import math
from joblib import Parallel, delayed

from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import log_loss

import warnings
warnings.filterwarnings("ignore")

# %%
# Set seed for reproducability
SEED = 2023
random.seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ### <font color="brown"> Import data

# %%
# import data for Iran - 12 months (2019-07-01 to 2020-06-30)

# Sentinel-2 (S2) data
train_data_iran1 = pd.read_csv('train_data_iran_2019_2020_month_0to100.csv')
train_data_iran2 = pd.read_csv('train_data_iran_2019_2020_month_100to200.csv')
train_data_iran3 = pd.read_csv('train_data_iran_2019_2020_month_200to300.csv')
train_data_iran4 = pd.read_csv('train_data_iran_2019_2020_month_300to400.csv')
train_data_iran5 = pd.read_csv('train_data_iran_2019_2020_month_400to500.csv')
train_data_iran_sentinel2 = pd.concat([train_data_iran1,train_data_iran2,train_data_iran3,train_data_iran4,train_data_iran5], axis=0).reset_index()

test_data_iran1 = pd.read_csv('test_data_iran_2019_2020_month_0to100.csv')
test_data_iran2 = pd.read_csv('test_data_iran_2019_2020_month_100to200.csv')
test_data_iran3 = pd.read_csv('test_data_iran_2019_2020_month_200to300.csv')
test_data_iran4 = pd.read_csv('test_data_iran_2019_2020_month_300to400.csv')
test_data_iran5 = pd.read_csv('test_data_iran_2019_2020_month_400to500.csv')
test_data_iran_sentinel2 = pd.concat([test_data_iran1,test_data_iran2,test_data_iran3,test_data_iran4,test_data_iran5], axis=0).reset_index()

# Sentinel-1 (S1) data
train_data_iran_sentinel1 = pd.read_csv('train_data_iran_sentinel1.csv')
test_data_iran_sentinel1 = pd.read_csv('test_data_iran_sentinel1.csv')

train_data_iran_S1S2 = pd.concat([train_data_iran_sentinel2, train_data_iran_sentinel1.iloc[:,4:]], axis=1)
test_data_iran_S1S2 = pd.concat([test_data_iran_sentinel2, test_data_iran_sentinel1.iloc[:,3:]], axis=1)

# Landsat-8 (L8) data
train_data_iran1 = pd.read_csv('train_data_iran_LANDSAT8_0to100.csv')
train_data_iran2 = pd.read_csv('train_data_iran_LANDSAT8_100to500.csv')
train_data_iran_landsat = pd.concat([train_data_iran1, train_data_iran2], axis=0).reset_index()
test_data_iran_landsat = pd.read_csv('test_data_iran_LANDSAT8.csv')

# %%
# import data for Sudan - 12 months (2019-07-01 to 2020-06-30)

# Sentinel-2 data
train_data_sudan1 = pd.read_csv('train_data_sudan_2019_2020_month_0to100.csv')
train_data_sudan2 = pd.read_csv('train_data_sudan_2019_2020_month_100to200.csv')
train_data_sudan3 = pd.read_csv('train_data_sudan_2019_2020_month_200to300.csv')
train_data_sudan4 = pd.read_csv('train_data_sudan_2019_2020_month_300to400.csv')
train_data_sudan5 = pd.read_csv('train_data_sudan_2019_2020_month_400to500.csv')
train_data_sudan_sentinel2 = pd.concat([train_data_sudan1,train_data_sudan2,train_data_sudan3,train_data_sudan4,train_data_sudan5], axis=0).reset_index()

test_data_sudan1 = pd.read_csv('test_data_sudan_2019_2020_month_0to100.csv')
test_data_sudan2 = pd.read_csv('test_data_sudan_2019_2020_month_100to200.csv')
test_data_sudan3 = pd.read_csv('test_data_sudan_2019_2020_month_200to300.csv')
test_data_sudan4 = pd.read_csv('test_data_sudan_2019_2020_month_300to400.csv')
test_data_sudan5 = pd.read_csv('test_data_sudan_2019_2020_month_400to500.csv')
test_data_sudan_sentinel2 = pd.concat([test_data_sudan1,test_data_sudan2,test_data_sudan3,test_data_sudan4,test_data_sudan5], axis=0).reset_index()

# Sentinel-1 data
train_data_sudan_sentinel1 = pd.read_csv('train_data_sudan_sentinel1.csv')
test_data_sudan_sentinel1 = pd.read_csv('test_data_sudan_sentinel1.csv')

train_data_sudan_S1S2 = pd.concat([train_data_sudan_sentinel2, train_data_sudan_sentinel1.iloc[:,4:]], axis=1)
test_data_sudan_S1S2 = pd.concat([test_data_sudan_sentinel2, test_data_sudan_sentinel1.iloc[:,3:]], axis=1)

# Landsat-8 data
train_data_sudan1 = pd.read_csv('train_data_sudan_LANDSAT8_0to250.csv')
train_data_sudan2 = pd.read_csv('train_data_sudan_LANDSAT8_250to500.csv')
train_data_sudan_landsat = pd.concat([train_data_sudan1, train_data_sudan2], axis=0).reset_index()

test_data_sudan1 = pd.read_csv('test_data_sudan_LANDSAT8_0to250.csv')
test_data_sudan2 = pd.read_csv('test_data_sudan_LANDSAT8_250to500.csv')
test_data_sudan_landsat = pd.concat([test_data_sudan1, test_data_sudan2], axis=0).reset_index()

# %%
# import data for Afghanistan

# Sentinel-2 data

## 1 month (2022-04-01 to 2022-04-30)
train_data_afghanistan_sentinel2_april = pd.read_csv('train_data_afghanistan_april.csv')
test_data_afghanistan_sentinel2_april = pd.read_csv('test_data_afghanistan_april.csv')

## 12 months (2021-04-01 to 2022-03-31)
train_data_afghanistan1 = pd.read_csv('train_data_afghanistan_2021_month_0to100.csv')
train_data_afghanistan2 = pd.read_csv('train_data_afghanistan_2021_month_100to200.csv')
train_data_afghanistan3 = pd.read_csv('train_data_afghanistan_2021_month_200to300.csv')
train_data_afghanistan4 = pd.read_csv('train_data_afghanistan_2021_month_300to400.csv')
train_data_afghanistan5 = pd.read_csv('train_data_afghanistan_2021_month_400to500.csv')
train_data_afghanistan_sentinel2 = pd.concat([train_data_afghanistan1,train_data_afghanistan2,train_data_afghanistan3,train_data_afghanistan4,train_data_afghanistan5], axis=0).reset_index()

test_data_afghanistan1 = pd.read_csv('test_data_afghanistan_2021_month_0to100.csv')
test_data_afghanistan2 = pd.read_csv('test_data_afghanistan_2021_month_100to200.csv')
test_data_afghanistan3 = pd.read_csv('test_data_afghanistan_2021_month_200to300.csv')
test_data_afghanistan4 = pd.read_csv('test_data_afghanistan_2021_month_300to400.csv')
test_data_afghanistan5 = pd.read_csv('test_data_afghanistan_2021_month_400to500.csv')
test_data_afghanistan_sentinel2 = pd.concat([test_data_afghanistan1,test_data_afghanistan2,test_data_afghanistan3,test_data_afghanistan4,test_data_afghanistan5], axis=0).reset_index()

# Sentinel-1 data

## 1 month (2022-04-01 to 2022-04-30)
train_data_afghanistan_sentinel1_april = pd.read_csv('train_data_afghanistan_sentinel1.csv')
test_data_afghanistan_sentinel1_april = pd.read_csv('test_data_afghanistan_sentinel1.csv')

## 12 months (2021-04-01 to 2022-03-31)
train_data_afghanistan_sentinel1 = pd.read_csv('train_data_afghanistan_2021_month_sentinel1.csv')
test_data_afghanistan_sentinel1 = pd.read_csv('test_data_afghanistan_2021_month_sentinel1.csv')

# Sentinel-1 and Sentinel-2 data for 1 month (2022-04-01 to 2022-04-30)
train_data_afghanistan_S1S2_april = pd.concat([train_data_afghanistan_sentinel2_april, train_data_afghanistan_sentinel1_april.iloc[:,4:]], axis=1)
test_data_afghanistan_S1S2_april = pd.concat([test_data_afghanistan_sentinel2_april, test_data_afghanistan_sentinel1_april.iloc[:,3:]], axis=1)

# Sentinel-1 and Sentinel-2 data for 12 months (2021-04-01 to 2022-03-31)
train_data_afghanistan_S1S2 = pd.concat([train_data_afghanistan_sentinel2, train_data_afghanistan_sentinel1.iloc[:,4:]], axis=1)
test_data_afghanistan_S1S2 = pd.concat([test_data_afghanistan_sentinel2, test_data_afghanistan_sentinel1.iloc[:,3:]], axis=1)

# Landsat-8 data for 12 months (2021-04-01 to 2022-03-31)
train_data_afghanistan1 = pd.read_csv('train_data_afghanistan_LANDSAT8_0to250.csv')
train_data_afghanistan2 = pd.read_csv('train_data_afghanistan_LANDSAT8_250to500.csv')
train_data_afghanistan_landsat = pd.concat([train_data_afghanistan1, train_data_afghanistan2], axis=0).reset_index()

test_data_afghanistan_landsat = pd.read_csv('test_data_afghanistan_LANDSAT8.csv')

# %% [markdown]
# ### <font color="brown"> Functions Utilized

# %%
# Create Features (or remote sensing indices) for 12 months

eps=1e-08

def vegetation_index(i):

  b01 = comb.filter(like = "B1_").values[:,i]
  b02 = comb.filter(like = "B2_").values[:,i]
  b03 = comb.filter(like = "B3_").values[:,i]
  b04 = comb.filter(like = "B4_").values[:,i]
  b05 = comb.filter(like = "B5_").values[:,i]
  b06 = comb.filter(like = "B6_").values[:,i]
  b07 = comb.filter(like = "B7_").values[:,i]
  b08 = comb.filter(like = "B8_").values[:,i]
  b8a = comb.filter(like = "B8A_").values[:,i]
  b09 = comb.filter(like = "B9_").values[:,i]
  b11 = comb.filter(like = "B11_").values[:,i]
  b12 = comb.filter(like = "B12_").values[:,i]

  MI = (b8a - b11) / (b8a + b11+ eps)
  ARVI_ =  (b08 - (2 * b04) + b02) / (b08 + (2 * b04) - b02+ eps)
  SIPI = (b08 - b02) / (b08 - b04+ eps)
  RENDVI = (b06 - b05) / (b06 + b05+ eps)
  MRESR = (b06 - b01) / (b05 - b01+ eps)
  RYI = b03 / (b02+ eps)
  NDYI = (b03 - b02) / (b03 + b02+ eps)
  DYI = b03 - b02
  ACI = b08 * (b04 + b03)
  AVI_ = (b08 * (1 - b04) * (b08 - b04))
  SI = ((1 - b02) * (1 - b03) * (1 - b04))
  BSI = ((b11 + b04) - (b08 + b02)) / ((b11 + b04) + (b08 + b02)+ eps)
  L = 0.33; SAVI = ((b08 - b04) / (b08 + b04 + L)) * (1 + L)
  FIDET = b12 / (b8a * b09+ eps)
  MTCI_ = (b06 - b05) / (b05 - b04+ eps)
  NPCRI = (b04 - b02) / (b04 + b02+ eps)
  S2REP = 705 + 35 * ((((b07 + b04) / 2) - b05) / (b06 - b05+ eps))
  CCCI = ((b08 - b05) / (b08 + b05+ eps)) / ((b08 - b04+ eps) / (b08 + b04+ eps))
  MCARI = ((b05 - b04) - 0.2 * (b05 - b03)) * (b05 / (b04+ eps))
  TCARI = 3 * ((b05 - b04) - 0.2 * (b05 - b03) * (b05 / (b04+ eps)))
  PVI = (b08 - 0.3 * b04 - 0.5) / ((1 + 0.3 * 2) ** (1 / 2.0))
  EVI = 2.5 * (b08 - b04) / (b08 + 6 * b04 - 7.5 * b02 + 1)
  EVI2 = 2.4 * (b08 - b04) / (b08 + b04 + 1)
  NDVI = ((b08 - b04) / (b08 + b04+ eps))
  NDVI2 = ((b12 - b08) / (b12 + b08+ eps))
  MNDVI = (b08 - b04) / (b08 + b04 - 2 * b02+ eps)
  BAI = 1 / ((0.1 - b04) ** 2 + (0.06 - b08) ** 2)
  NDSI = (b03 - b11) / (b03 + b11+ eps)
  MRENDVI = (b06 - b05) / (b06 + b05 - 2 * b01+ eps)
  NDVIre = (b08 - b05) / (b08 + b05+ eps)
  CIre = ((b08 / (b05+ eps)) - 1)
  NDMI = (b08 - b11) / (b08 + b11+ eps)
  TNDVI = [(x) ** (1 / 2.0) for x in ((b08 - b04) / (b08 + b04) + 0.5)]
  SWIRmin = 0.378; SWIRmax = 0.397; SWIIRmin = 0.027; NDVIc = (b08 - b04) / (b08 + b04) * (1.0 - (b12 - SWIIRmin) / (SWIRmax - SWIRmin))
  VDVI = (2 * b03 - b04 - b02) / (2 * b03 + b04 + b02+ eps)
  TVI = (120 * (b06 - b03) - 200 * (b04 - b03)) / 2
  EXG = 2 * b03 - b04 - b02
  PSRI = (b04 - b02) / (b06+ eps)
  RDVI = [(i - j) / (i + j) ** (1 / 2.0) for i, j in zip(b08, b04)]
  RATIO1 = b01 / (b03+ eps)
  RATIO2 = b01 / (b05+ eps)
  RATIO3 = b11 / (b12+ eps)
  RATIO4 = b05 / (b04+ eps)
  NDWI = (b03 - b08) / (b03 + b08+ eps)
  NDRE = (b09 - b05) / (b09 + b05+ eps)
  NDRE_ = (b05 - b04) / (b05 + b04+ eps)
  NDRE7 = (b07 - b04) / (b07 + b04+ eps)
  MSI = b11 / (b8a+ eps)
  RECI = (b08 / (b04+ eps)) - 1
  VARI = (b03 - b04) / (b03 + b04 - b02+ eps)
  MTCI = (b8a - b06) / (b07 + b06+ eps)
  ExBlue = (2 * b02) - (b03 + b04)
  WDRVI = (0.1 * b08 - b04) / (0.1 * b08 + b04+ eps)
  GRNDVI = (b08 - (b03 + b04)) / (b08 + (b03 + b04)+ eps)
  LCI = (b08 - b05) / (b08 + b04+ eps)
  BNDVI = (b08 - b02) / (b08 + b02+ eps)
  AFRI = b08 - 0.66 * (b11 / (b08 + 0.66 * b11+ eps))
  aci = b08 * (b04 + b03)
  bai = 1 / ((0.1 - b04) ** 2 + (0.06 - b08) ** 2)
  NLI = (b08 ** 2 - b04) / (b08 ** 2 + b04+ eps)
  b7b5 = (b07 - b05) / (b07 + b05+ eps)
  b7b6 = (b07 - b06) / (b07 + b06+ eps)
  b8ab5 = (b8a - b05) / (b8a + b05+ eps)
  ATSAVI = 1.22 * (b08 - 1.22 * b04 - 0.03) / (1.22 * b08 + b04 - 1.22 * 0.03 + 0.08 * (1.0 + np.power(1.22, 2.0)))
  AFRI2100 = b08 - 0.5 * b12 / (b08 + 0.56 * b12+ eps)
  ARI = 1.0 / (b03+ eps) - 1.0 / (b05+ eps)
  AVI = 2.0 * b09 - b04
  yy = 0.106; ARVI = (b8a - b04 - yy * (b04 - b02)) / (b8a + b04 - yy * (b04 - b02)+ eps)
  ARVI2 = -0.18 + 1.17 * ((b08 - b04) / (b08 + b04+ eps))
  BWDRVI = (0.1 * b08 - b02) / (0.1 * b08 + b02+ eps)
  BRI = (1.0 / (b03+ eps) - 1.0 / (b05+ eps)) / (b08+ eps)
  CARI = (b05 / (b04+ eps)) * (np.sqrt(np.power(((b05 - b03) / 150.0 * 670.0 + b04 + (b03 - ((b05 - b03) / 150.0 * 550.0))), 2.0))) / (np.power(((b05 - b03) / np.power(150.0, 2.0) + 1.0), 0.5))
  aaa = 0.496; CARI2 = (np.abs(((b05 - b03) / 150.0 * b04 + b04 + b03 - (aaa * b03))) / np.power((np.power(aaa, 2.0) + 1.0), 0.5)) * (b05 / b04)
  Chlgreen = np.power((b07 / (b03+ eps)), (-1.0))
  CIgreen = b08 / (b03+ eps) - 1.0
  Chlrededge = np.power((b07 / b05), (-1.0))
  CVI = b08 * b04 / np.power(b03, 2.0)
  CI = (b04 - b02) / (b04+ eps)
  CTVI = (((b04 - b03) / (b04 + b03)) + 0.5) / np.abs(((b04 - b03) / (b04 + b03)) + 0.5) * np.sqrt(np.abs((((b04 - b03) / (b04 + b03))) + 0.5))
  CRI550 = np.power(b02, (-1.0)) - np.power(b03, (-1.0))
  CRI700 = np.power(b02, (-1.0)) - np.power(b05, (-1.0))
  Datt1 = (b08 - b05) / (b08 - b04+ eps)
  Datt4 = b04 / ((b03 * b05)+ eps)
  Datt6 = b8a / ((b03 * b05)+ eps)
  D678500 = b04 - b02
  D800550 = b08 - b03
  D800680 = b08 - b04
  DVIMSS = 2.4 * b09 - b04
  EVI2_ = 2.5 * (b08 - b04) / (b08 + 2.4 * b04 + 1.0)
  aa = 0.331; bb = 0.329; EPI = aa * b04 / np.power((b03 * b05), bb)
  Fe2 = b12 / (b08+ eps) + b03 / (b04+ eps)
  Fe3 = b04 / (b03+ eps)
  Fo = b11 / (b08+ eps)
  GEMI = ((2.0 * (np.power(b08, 2.0) - np.power(b04, 2.0)) + 1.5 * b08 + 0.5 * b04) / (b08 + b04 + 0.5) * (1.0 - 0.25 * (2.0 * (np.power(b08, 2.0) - np.power(b04, 2.0)) + 1.5 * b08 + 0.5 * b04) / (b08 + b04 + 0.5)) - (b04 - 0.125) / (1.0 - b04))
  GVMI = ((b08 + 0.1) - (b12 + 0.02)) / ((b08 + 0.1) + (b12 + 0.02+ eps))
  Gossan = b11 / (b04+ eps)
  GARI = (b08 - (b03 - (b02 - b04))) / (b08 - (b03 + (b02 - b04))+ eps)
  GLI = (2.0 * b03 - b04 - b02) / (2.0 * b03 + b04 + b02+ eps)
  YY = 0.120; GOSAVI = (b08 - b03) / (b08 + b03 + YY)
  L = 0.482; GSAVI = (b08 - b03) / (b08 + b03 + L) * (1.0 + L)
  GBNDVI = (b08 - (b03 + b02)) / (b08 + (b03 + b02)+ eps)
  H = np.arctan((2.0 * b04 - b03 - b02) / 30.5 * (b03 - b02+ eps))
  a = 0.393; b = 0.809; IVI = (b08 - b) / (a * b04+ eps)
  IPVI = (b09 / (b09 + b05+ eps)) / 2 * (((b05 - b03) / (b05 + b03+ eps)) + 1)
  I = (1.0 / (30.5)) * (b04 + b03 + b02)
  IR550 = np.power(b03, (-1.0))
  IR700 = np.power(b05, (-1.0))
  MIDIR = 0.101; LWCI = np.log(1.0 - (b08 - MIDIR)) / (-np.log(1.0 - (b08 - MIDIR)))
  LogR = np.log(b08 / (b04+ eps))
  Maccioni = (b07 - b05) / (b07 - b04+ eps)
  mCRIG = (np.power(b02, (-1.0)) - np.power(b03, (-1.0))) * b08
  mCRIRE = (np.power(b02, (-1.0)) - np.power(b05, (-1.0))) * b08
  MVI = b09 / (b11+ eps)
  MGVI = -0.386 * b03 - 0.53 * b04 + 0.535 * b06 + 0.532 * b09
  MNSI = 0.404 * b03 - 0.039 * b04 - 0.505 * b06 + 0.762 * b09
  MSBI = 0.406 * b03 + 0.6 * b04 + 0.645 * b06 + 0.243 * b09
  MYVI = 0.723 * b03 - 0.597 * b04 + 0.206 * b06 - 0.278 * b09
  mND680 = (b08 - b04) / (b08 + b04 - 2.0 * b01+ eps)
  mARI = (np.power(b03, (-1.0)) - np.power(b05, (-1.0))) * b08
  MCARI1 = 1.2 * (2.5 * (b08 - b04) - 1.3 * (b08 - b03))
  MCARI2 = 1.5 * (2.5 * (b08 - b04) - 1.3 * (b08 - b03)) / np.sqrt(np.power((2.0 * b08 + 1.0), 2.0) - (6.0 * b08 - 5.0 * np.sqrt(b04)) - 0.5)
  MCARIMTVI2 = (((b05 - b04) - 0.2 * (b05 - b03)) * (b05 / (b04+ eps))) / (1.5 * (1.2 * (b08 - b03) - 2.5 * (b04 - b03)) / np.sqrt(np.power((2.0 * b08 + 1.0), 2.0) - (6.0 * b08 - 5.0 * np.sqrt(b04)) - 0.5))
  MCARIOSAVI = ((b05 - b04) - 0.2 * (b05 - b03) * (b05 / (b04+ eps))) / ((1.0 + 0.16) * (b08 - b04) / (b08 + b04 + 0.16))
  mSR = (b08 - b01) / (b04 - b01+ eps)
  MSRNirRed = ((b08 / (b04+ eps)) - 1.0) / np.sqrt((b08 / (b04+ eps)) + 1.0)
  MSAVI = (2.0 * b08 + 1.0 - np.sqrt(np.power((2.0 * b08 + 1.0), 2.0) - 8.0 * (b08 - b04))) / 2.0
  MSAVIhyper = (0.5) * ((2.0 * b08 + 1.0) - np.sqrt(np.power((2.0 * b08 + 1.0), 2.0) - 8.0 * (b08 - b04)))
  MTVI1 = 1.2 * (1.2 * (b08 - b03) - 2.5 * (b04 - b03))
  MTVI2 = 1.5 * (1.2 * (b08 - b03) - 2.5 * (b04 - b03)) / np.sqrt(np.power((2.0 * b08 + 1.0), 2.0) - (6.0 * b08 - 5.0 * np.sqrt(b04)) - 0.5)
  NormG = b03 / (b08 + b04 + b03+ eps)
  NormR = b04 / (b08 + b04 + b03+ eps)
  NormNIR = b08 / (b08 + b04 + b03+ eps)
  PPR = (b03 - b01) / (b03 + b01+ eps)
  PVR = (b03 - b04) / (b03 + b04+ eps)
  GNDVIhyper = (b07 - b03) / (b07 + b03+ eps)
  OSAVI = (1.0 + 0.16) * (b08 - b04) / (b08 + b04 + 0.16)
  PNDVI = (b08 - (b03 + b04 + b02)) / (b08 + (b03 + b04 + b02)+ eps)
  a = 0.149; ar = 0.374; b = 0.735; PVI_ = (1.0 / np.sqrt(a ** 2.0 + 1.0)) * (b08 - ar - b)
  r700 = 0.715; r675 = 0.722; RARSa1 = (b04 / b05) / (r675 / r700)
  r700 = 0.989; r680 = 0.848; RARSa2 = (b04 / b05) / (r680 / r700)
  r670 = 0.382; r800 = 0.935; RARSa3 = (b04 / b08) / (r670 / r800)
  r680 = 0.523; r800 = 0.866; RARSa4 = (b04 / b08) / (r680 / r800)
  r500 = 0.535; r800 = 0.712; RARSc3 = (b08 / b02) / (r800 / r500)
  r470 = 0.503; r800 = 0.153; RARSc4 = (b08 / b02) / (r800 / r470)
  RBNDVI = (b08 - (b04 + b02)) / (b08 + (b04 + b02)+ eps)
  REIP1 = 700.0 + 40.0 * ((((b04 + b07) / 2.0) - b05) / (b06 - b05+ eps))
  REIP2 = 702.0 + 40.0 * ((((b04 + b07) / 2.0) - b05) / (b06 - b05+ eps))
  Rre = (b04 + b07) / 2.0
  MIRmin = 0.259; MIRmax = 0.640; RSR = b08 / b04 * MIRmax - b12 / MIRmax - MIRmin
  L = 0.781; SAVImir = (b08 - b12) * (1.0 + L) / (b08 + b12 + L)
  IF = (2.0 * b04 - b03 - b02) / (b03 - b02+ eps)
  SR440740 = b01 / (b06+ eps)
  SR520670 = b02 / (b04+ eps)
  SR700 = 1.0 / (b05+ eps)
  SR735710 = b06 / (b05+ eps)
  SR774677 = b07 / (b04+ eps)
  PSSRc1 = b08 / (b02+ eps)
  SR8002170 = b08 / (b12+ eps)
  SR860550 = b8a / (b03+ eps)
  SR860708 = b8a / (b05+ eps)
  SRMIRRed = b12 / (b04+ eps)
  SWIRI = 0.887; SRSWIRINIR = SWIRI / (b08+ eps)
  a = 0.064; b = 0.918; SAVI2 = b08 / (b04 + b / a)
  y = 0.735; Rr = 0.740; L = 0.487; RB = 0.560; SARVI = (1.0 + L) * (b08 - (Rr - y * (RB - Rr))) / (b08 + -(Rr - y * (RB - Rr)) + L)
  SLAVI = b08 / (b04 + b12+ eps)
  SQRT_ = np.sqrt(b08 / b04+ eps)
  SIPI_ = (b08 - b01) / (b08 - b04+ eps)
  GVIMSS = -0.283 * b03 - 0.66 * b04 + 0.577 * b06 + 0.388 * b09
  NSIMSS = -0.016 * b03 + 0.131 * b04 - 0.425 * b06 + 0.882 * b09
  SBIMSS = 0.332 * b03 + 0.603 * b04 + 0.675 * b06 + 0.262 * b09
  GVI = -0.2848 * b02 - 0.2435 * b03 - 0.5436 * b04 + 0.7243 * b08 + 0.084 * b11 - 0.18 * b12
  WET = 0.1509 * b02 + 0.1973 * b03 + 0.3279 * b04 + 0.3406 * b08 - 0.7112 * b11 - 0.4572 * b12
  YVIMSS = -0.899 * b03 + 0.428 * b04 + 0.076 * b06 - 0.041 * b09
  X = 0.114; A = 0.824; B = 0.421; TSAVI = (B * (b08 - B * b04 - A)) / (b04 + B * (b08 - A) + X * (1.0 + np.power(B, 2.0))+ eps)
  a = 0.419; b = 0.787; TSAVI2 = (a * b08 - a * b04 - b) / (b04 + a * b08 - a * b+ eps)
  TVI_ = np.sqrt((((b04 - b03) / (b04 + b03+ eps))) + 0.5)
  TCI = 1.2 * (b05 - b03) - 1.5 * (b04 - b03) * np.sqrt(b05 / (b04+ eps))
  VARI700 = (b05 - 1.7 * b04 + 0.7 * b02) / (b05 + 2.3 * b04 - 1.3 * b02+ eps)
  a = 0.752; WDVI = b08 - a * b04
  EPIChlb = 0.0337 * np.power((b04 / (b03+ eps)), 1.8695)
  LAI_green = 5.405 * b8ab5 - 0.114

  return [MI, ARVI_, SIPI, RENDVI, MRESR, RYI, NDYI, DYI, ACI, AVI_, SI, BSI, SAVI, FIDET, MTCI_, NPCRI, S2REP, CCCI, MCARI, TCARI,\
          PVI, EVI, NDVI, BAI, NDSI, MRENDVI, NDVIre, CIre, NDMI, TNDVI, VDVI, NDVIc, TVI, EXG, PSRI, RDVI, RATIO1, RATIO2, RATIO3, RATIO4,\
          NDVI2, NDWI, NDRE, NDRE_, NDRE7, MSI, RECI, b7b5, b7b6, b8ab5, VARI, MTCI, ExBlue, WDRVI, GRNDVI, LCI, BNDVI, AFRI, aci, bai,\
          NLI, EVI2, ATSAVI, AFRI2100, ARI, AVI, ARVI, ARVI2, BWDRVI, BRI, CARI, CARI2, Chlgreen, CIgreen, Chlrededge, CVI, CI, CTVI, CRI550, CRI700,\
          Datt1, Datt4, Datt6, D678500, D800550, D800680, DVIMSS, EVI2_, EPI, Fe2, Fe3, Fo, GEMI, GVMI, Gossan, GARI, GLI, GOSAVI, GSAVI, GBNDVI,\
          H, IVI, IPVI, I, IR550, IR700, LWCI, LogR, Maccioni, mCRIG, mCRIRE, MVI, MGVI, MNSI, MSBI, MYVI, mND680, mARI, MCARI1, MCARI2,\
          MCARIMTVI2, MCARIOSAVI, mSR, MSRNirRed, MSAVI, MSAVIhyper, MTVI1, MTVI2, NormG, NormR, NormNIR, PPR, PVR, GNDVIhyper, OSAVI, PNDVI, PVI_, RARSa1, RARSa2, RARSa3,\
          RARSa4, RARSc3, RARSc4, RBNDVI, REIP1, REIP2, Rre, RSR, SAVImir, IF, SR440740, SR520670, SR700, SR735710, SR774677, PSSRc1, SR8002170, SR860550, SR860708, SRMIRRed,\
          SRSWIRINIR, SAVI2, SARVI, SLAVI, SQRT_, SIPI_, GVIMSS, NSIMSS, SBIMSS, GVI, WET, YVIMSS, TSAVI, TSAVI2, TVI_, TCI, VARI700, WDVI, MNDVI, EPIChlb, LAI_green]

spectral_indices = ['MI', 'ARVI_', 'SIPI', 'RENDVI', 'MRESR', 'RYI', 'NDYI', 'DYI', 'ACI', 'AVI_', 'SI', 'BSI','SAVI', 'FIDET', 'MTCI_', 'NPCRI', 'S2REP', 'CCCI', 'MCARI', 'TCARI',\
                    'PVI', 'EVI', 'NDVI', 'BAI', 'NDSI', 'MRENDVI', 'NDVIre', 'CIre', 'NDMI', 'TNDVI', 'VDVI', 'NDVIc', 'TVI', 'EXG', 'PSRI', 'RDVI', 'RATIO1', 'RATIO2', 'RATIO3', 'RATIO4',\
                    'NDVI2', 'NDWI', 'NDRE', 'NDRE_', 'NDRE7', 'MSI', 'RECI', 'b7b5', 'b7b6', 'b8ab5', 'VARI', 'MTCI', 'ExBlue', 'WDRVI', 'GRNDVI', 'LCI', 'BNDVI', 'AFRI', 'aci', 'bai',\
                    'NLI', 'EVI2', 'ATSAVI', 'AFRI2100', 'ARI', 'AVI', 'ARVI', 'ARVI2', 'BWDRVI', 'BRI', 'CARI', 'CARI2', 'Chlgreen', 'CIgreen', 'Chlrededge', 'CVI', 'CI', 'CTVI', 'CRI550', 'CRI700',\
                    'Datt1', 'Datt4', 'Datt6', 'D678500', 'D800550', 'D800680', 'DVIMSS', 'EVI2_', 'EPI', 'Fe2', 'Fe3', 'Fo', 'GEMI', 'GVMI', 'Gossan', 'GARI', 'GLI', 'GOSAVI', 'GSAVI', 'GBNDVI',\
                    'H', 'IVI', 'IPVI', 'I', 'IR550', 'IR700', 'LWCI', 'LogR', 'Maccioni', 'mCRIG', 'mCRIRE', 'MVI', 'MGVI', 'MNSI', 'MSBI', 'MYVI', 'mND680', 'mARI', 'MCARI1', 'MCARI2',\
                    'MCARIMTVI2', 'MCARIOSAVI', 'mSR', 'MSRNirRed', 'MSAVI', 'MSAVIhyper', 'MTVI1', 'MTVI2', 'NormG', 'NormR', 'NormNIR', 'PPR', 'PVR', 'GNDVIhyper', 'OSAVI', 'PNDVI', 'PVI_', 'RARSa1', 'RARSa2', 'RARSa3',\
                    'RARSa4', 'RARSc3', 'RARSc4', 'RBNDVI', 'REIP1', 'REIP2', 'Rre', 'RSR', 'SAVImir', 'IF', 'SR440740', 'SR520670', 'SR700', 'SR735710', 'SR774677', 'PSSRc1', 'SR8002170', 'SR860550', 'SR860708', 'SRMIRRed',\
                    'SRSWIRINIR', 'SAVI2', 'SARVI', 'SLAVI', 'SQRT_', 'SIPI_', 'GVIMSS', 'NSIMSS', 'SBIMSS', 'GVI', 'WET', 'YVIMSS', 'TSAVI', 'TSAVI2', 'TVI_', 'TCI', 'VARI700', 'WDVI', 'MNDVI', 'EPIChlb', 'LAI_green']

# %%
len(spectral_indices)
# Out:
# 181

# %%
# Create Features (or remote sensing indices) for 1 month

def vegetation_index_month(i):
  b01 = comb["B1"]
  b02 = comb["B2"]
  b03 = comb["B3"]
  b04 = comb["B4"]
  b05 = comb["B5"]
  b06 = comb["B6"]
  b07 = comb["B7"]
  b08 = comb["B8"]
  b8a = comb["B8A"]
  b09 = comb["B9"]
  b11 = comb["B11"]
  b12 = comb["B12"]

  MI = (b8a - b11) / (b8a + b11+ eps)
  ARVI_ =  (b08 - (2 * b04) + b02) / (b08 + (2 * b04) - b02+ eps)
  SIPI = (b08 - b02) / (b08 - b04+ eps)
  RENDVI = (b06 - b05) / (b06 + b05+ eps)
  MRESR = (b06 - b01) / (b05 - b01+ eps)
  RYI = b03 / (b02+ eps)
  NDYI = (b03 - b02) / (b03 + b02+ eps)
  DYI = b03 - b02
  ACI = b08 * (b04 + b03)
  AVI_ = (b08 * (1 - b04) * (b08 - b04))
  SI = ((1 - b02) * (1 - b03) * (1 - b04))
  BSI = ((b11 + b04) - (b08 + b02)) / ((b11 + b04) + (b08 + b02)+ eps)
  L = 0.33; SAVI = ((b08 - b04) / (b08 + b04 + L)) * (1 + L)
  FIDET = b12 / (b8a * b09+ eps)
  MTCI_ = (b06 - b05) / (b05 - b04+ eps)
  NPCRI = (b04 - b02) / (b04 + b02+ eps)
  S2REP = 705 + 35 * ((((b07 + b04) / 2) - b05) / (b06 - b05+ eps))
  CCCI = ((b08 - b05) / (b08 + b05+ eps)) / ((b08 - b04+ eps) / (b08 + b04+ eps))
  MCARI = ((b05 - b04) - 0.2 * (b05 - b03)) * (b05 / (b04+ eps))
  TCARI = 3 * ((b05 - b04) - 0.2 * (b05 - b03) * (b05 / (b04+ eps)))
  PVI = (b08 - 0.3 * b04 - 0.5) / ((1 + 0.3 * 2) ** (1 / 2.0))
  EVI = 2.5 * (b08 - b04) / (b08 + 6 * b04 - 7.5 * b02 + 1)
  EVI2 = 2.4 * (b08 - b04) / (b08 + b04 + 1)
  NDVI = ((b08 - b04) / (b08 + b04+ eps))
  NDVI2 = ((b12 - b08) / (b12 + b08+ eps))
  MNDVI = (b08 - b04) / (b08 + b04 - 2 * b02+ eps)
  BAI = 1 / ((0.1 - b04) ** 2 + (0.06 - b08) ** 2)
  NDSI = (b03 - b11) / (b03 + b11+ eps)
  MRENDVI = (b06 - b05) / (b06 + b05 - 2 * b01+ eps)
  NDVIre = (b08 - b05) / (b08 + b05+ eps)
  CIre = ((b08 / (b05+ eps)) - 1)
  NDMI = (b08 - b11) / (b08 + b11+ eps)
  TNDVI = [(x) ** (1 / 2.0) for x in ((b08 - b04) / (b08 + b04) + 0.5)]
  SWIRmin = 0.378; SWIRmax = 0.397; SWIIRmin = 0.027; NDVIc = (b08 - b04) / (b08 + b04) * (1.0 - (b12 - SWIIRmin) / (SWIRmax - SWIRmin))
  VDVI = (2 * b03 - b04 - b02) / (2 * b03 + b04 + b02+ eps)
  TVI = (120 * (b06 - b03) - 200 * (b04 - b03)) / 2
  EXG = 2 * b03 - b04 - b02
  PSRI = (b04 - b02) / (b06+ eps)
  RDVI = [(i - j) / (i + j) ** (1 / 2.0) for i, j in zip(b08, b04)]
  RATIO1 = b01 / (b03+ eps)
  RATIO2 = b01 / (b05+ eps)
  RATIO3 = b11 / (b12+ eps)
  RATIO4 = b05 / (b04+ eps)
  NDWI = (b03 - b08) / (b03 + b08+ eps)
  NDRE = (b09 - b05) / (b09 + b05+ eps)
  NDRE_ = (b05 - b04) / (b05 + b04+ eps)
  NDRE7 = (b07 - b04) / (b07 + b04+ eps)
  MSI = b11 / (b8a+ eps)
  RECI = (b08 / (b04+ eps)) - 1
  VARI = (b03 - b04) / (b03 + b04 - b02+ eps)
  MTCI = (b8a - b06) / (b07 + b06+ eps)
  ExBlue = (2 * b02) - (b03 + b04)
  WDRVI = (0.1 * b08 - b04) / (0.1 * b08 + b04+ eps)
  GRNDVI = (b08 - (b03 + b04)) / (b08 + (b03 + b04)+ eps)
  LCI = (b08 - b05) / (b08 + b04+ eps)
  BNDVI = (b08 - b02) / (b08 + b02+ eps)
  AFRI = b08 - 0.66 * (b11 / (b08 + 0.66 * b11+ eps))
  aci = b08 * (b04 + b03)
  bai = 1 / ((0.1 - b04) ** 2 + (0.06 - b08) ** 2)
  NLI = (b08 ** 2 - b04) / (b08 ** 2 + b04+ eps)
  b7b5 = (b07 - b05) / (b07 + b05+ eps)
  b7b6 = (b07 - b06) / (b07 + b06+ eps)
  b8ab5 = (b8a - b05) / (b8a + b05+ eps)
  ATSAVI = 1.22 * (b08 - 1.22 * b04 - 0.03) / (1.22 * b08 + b04 - 1.22 * 0.03 + 0.08 * (1.0 + np.power(1.22, 2.0)))
  AFRI2100 = b08 - 0.5 * b12 / (b08 + 0.56 * b12+ eps)
  ARI = 1.0 / (b03+ eps) - 1.0 / (b05+ eps)
  AVI = 2.0 * b09 - b04
  yy = 0.106; ARVI = (b8a - b04 - yy * (b04 - b02)) / (b8a + b04 - yy * (b04 - b02)+ eps)
  ARVI2 = -0.18 + 1.17 * ((b08 - b04) / (b08 + b04+ eps))
  BWDRVI = (0.1 * b08 - b02) / (0.1 * b08 + b02+ eps)
  BRI = (1.0 / (b03+ eps) - 1.0 / (b05+ eps)) / (b08+ eps)
  CARI = (b05 / (b04+ eps)) * (np.sqrt(np.power(((b05 - b03) / 150.0 * 670.0 + b04 + (b03 - ((b05 - b03) / 150.0 * 550.0))), 2.0))) / (np.power(((b05 - b03) / np.power(150.0, 2.0) + 1.0), 0.5))
  aaa = 0.496; CARI2 = (np.abs(((b05 - b03) / 150.0 * b04 + b04 + b03 - (aaa * b03))) / np.power((np.power(aaa, 2.0) + 1.0), 0.5)) * (b05 / b04)
  Chlgreen = np.power((b07 / (b03+ eps)), (-1.0))
  CIgreen = b08 / (b03+ eps) - 1.0
  Chlrededge = np.power((b07 / b05), (-1.0))
  CVI = b08 * b04 / np.power(b03, 2.0)
  CI = (b04 - b02) / (b04+ eps)
  CTVI = (((b04 - b03) / (b04 + b03)) + 0.5) / np.abs(((b04 - b03) / (b04 + b03)) + 0.5) * np.sqrt(np.abs((((b04 - b03) / (b04 + b03))) + 0.5))
  CRI550 = np.power(b02, (-1.0)) - np.power(b03, (-1.0))
  CRI700 = np.power(b02, (-1.0)) - np.power(b05, (-1.0))
  Datt1 = (b08 - b05) / (b08 - b04+ eps)
  Datt4 = b04 / ((b03 * b05)+ eps)
  Datt6 = b8a / ((b03 * b05)+ eps)
  D678500 = b04 - b02
  D800550 = b08 - b03
  D800680 = b08 - b04
  DVIMSS = 2.4 * b09 - b04
  EVI2_ = 2.5 * (b08 - b04) / (b08 + 2.4 * b04 + 1.0)
  aa = 0.331; bb = 0.329; EPI = aa * b04 / np.power((b03 * b05), bb)
  Fe2 = b12 / (b08+ eps) + b03 / (b04+ eps)
  Fe3 = b04 / (b03+ eps)
  Fo = b11 / (b08+ eps)
  GEMI = ((2.0 * (np.power(b08, 2.0) - np.power(b04, 2.0)) + 1.5 * b08 + 0.5 * b04) / (b08 + b04 + 0.5) * (1.0 - 0.25 * (2.0 * (np.power(b08, 2.0) - np.power(b04, 2.0)) + 1.5 * b08 + 0.5 * b04) / (b08 + b04 + 0.5)) - (b04 - 0.125) / (1.0 - b04))
  GVMI = ((b08 + 0.1) - (b12 + 0.02)) / ((b08 + 0.1) + (b12 + 0.02+ eps))
  Gossan = b11 / (b04+ eps)
  GARI = (b08 - (b03 - (b02 - b04))) / (b08 - (b03 + (b02 - b04))+ eps)
  GLI = (2.0 * b03 - b04 - b02) / (2.0 * b03 + b04 + b02+ eps)
  YY = 0.120; GOSAVI = (b08 - b03) / (b08 + b03 + YY)
  L = 0.482; GSAVI = (b08 - b03) / (b08 + b03 + L) * (1.0 + L)
  GBNDVI = (b08 - (b03 + b02)) / (b08 + (b03 + b02)+ eps)
  H = np.arctan((2.0 * b04 - b03 - b02) / 30.5 * (b03 - b02+ eps))
  a = 0.393; b = 0.809; IVI = (b08 - b) / (a * b04+ eps)
  IPVI = (b09 / (b09 + b05+ eps)) / 2 * (((b05 - b03) / (b05 + b03+ eps)) + 1)
  I = (1.0 / (30.5)) * (b04 + b03 + b02)
  IR550 = np.power(b03, (-1.0))
  IR700 = np.power(b05, (-1.0))
  MIDIR = 0.101; LWCI = np.log(1.0 - (b08 - MIDIR)) / (-np.log(1.0 - (b08 - MIDIR)))
  LogR = np.log(b08 / (b04+ eps))
  Maccioni = (b07 - b05) / (b07 - b04+ eps)
  mCRIG = (np.power(b02, (-1.0)) - np.power(b03, (-1.0))) * b08
  mCRIRE = (np.power(b02, (-1.0)) - np.power(b05, (-1.0))) * b08
  MVI = b09 / (b11+ eps)
  MGVI = -0.386 * b03 - 0.53 * b04 + 0.535 * b06 + 0.532 * b09
  MNSI = 0.404 * b03 - 0.039 * b04 - 0.505 * b06 + 0.762 * b09
  MSBI = 0.406 * b03 + 0.6 * b04 + 0.645 * b06 + 0.243 * b09
  MYVI = 0.723 * b03 - 0.597 * b04 + 0.206 * b06 - 0.278 * b09
  mND680 = (b08 - b04) / (b08 + b04 - 2.0 * b01+ eps)
  mARI = (np.power(b03, (-1.0)) - np.power(b05, (-1.0))) * b08
  MCARI1 = 1.2 * (2.5 * (b08 - b04) - 1.3 * (b08 - b03))
  MCARI2 = 1.5 * (2.5 * (b08 - b04) - 1.3 * (b08 - b03)) / np.sqrt(np.power((2.0 * b08 + 1.0), 2.0) - (6.0 * b08 - 5.0 * np.sqrt(b04)) - 0.5)
  MCARIMTVI2 = (((b05 - b04) - 0.2 * (b05 - b03)) * (b05 / (b04+ eps))) / (1.5 * (1.2 * (b08 - b03) - 2.5 * (b04 - b03)) / np.sqrt(np.power((2.0 * b08 + 1.0), 2.0) - (6.0 * b08 - 5.0 * np.sqrt(b04)) - 0.5))
  MCARIOSAVI = ((b05 - b04) - 0.2 * (b05 - b03) * (b05 / (b04+ eps))) / ((1.0 + 0.16) * (b08 - b04) / (b08 + b04 + 0.16))
  mSR = (b08 - b01) / (b04 - b01+ eps)
  MSRNirRed = ((b08 / (b04+ eps)) - 1.0) / np.sqrt((b08 / (b04+ eps)) + 1.0)
  MSAVI = (2.0 * b08 + 1.0 - np.sqrt(np.power((2.0 * b08 + 1.0), 2.0) - 8.0 * (b08 - b04))) / 2.0
  MSAVIhyper = (0.5) * ((2.0 * b08 + 1.0) - np.sqrt(np.power((2.0 * b08 + 1.0), 2.0) - 8.0 * (b08 - b04)))
  MTVI1 = 1.2 * (1.2 * (b08 - b03) - 2.5 * (b04 - b03))
  MTVI2 = 1.5 * (1.2 * (b08 - b03) - 2.5 * (b04 - b03)) / np.sqrt(np.power((2.0 * b08 + 1.0), 2.0) - (6.0 * b08 - 5.0 * np.sqrt(b04)) - 0.5)
  NormG = b03 / (b08 + b04 + b03+ eps)
  NormR = b04 / (b08 + b04 + b03+ eps)
  NormNIR = b08 / (b08 + b04 + b03+ eps)
  PPR = (b03 - b01) / (b03 + b01+ eps)
  PVR = (b03 - b04) / (b03 + b04+ eps)
  GNDVIhyper = (b07 - b03) / (b07 + b03+ eps)
  OSAVI = (1.0 + 0.16) * (b08 - b04) / (b08 + b04 + 0.16)
  PNDVI = (b08 - (b03 + b04 + b02)) / (b08 + (b03 + b04 + b02)+ eps)
  a = 0.149; ar = 0.374; b = 0.735; PVI_ = (1.0 / np.sqrt(a ** 2.0 + 1.0)) * (b08 - ar - b)
  r700 = 0.715; r675 = 0.722; RARSa1 = (b04 / b05) / (r675 / r700)
  r700 = 0.989; r680 = 0.848; RARSa2 = (b04 / b05) / (r680 / r700)
  r670 = 0.382; r800 = 0.935; RARSa3 = (b04 / b08) / (r670 / r800)
  r680 = 0.523; r800 = 0.866; RARSa4 = (b04 / b08) / (r680 / r800)
  r500 = 0.535; r800 = 0.712; RARSc3 = (b08 / b02) / (r800 / r500)
  r470 = 0.503; r800 = 0.153; RARSc4 = (b08 / b02) / (r800 / r470)
  RBNDVI = (b08 - (b04 + b02)) / (b08 + (b04 + b02)+ eps)
  REIP1 = 700.0 + 40.0 * ((((b04 + b07) / 2.0) - b05) / (b06 - b05+ eps))
  REIP2 = 702.0 + 40.0 * ((((b04 + b07) / 2.0) - b05) / (b06 - b05+ eps))
  Rre = (b04 + b07) / 2.0
  MIRmin = 0.259; MIRmax = 0.640; RSR = b08 / b04 * MIRmax - b12 / MIRmax - MIRmin
  L = 0.781; SAVImir = (b08 - b12) * (1.0 + L) / (b08 + b12 + L)
  IF = (2.0 * b04 - b03 - b02) / (b03 - b02+ eps)
  SR440740 = b01 / (b06+ eps)
  SR520670 = b02 / (b04+ eps)
  SR700 = 1.0 / (b05+ eps)
  SR735710 = b06 / (b05+ eps)
  SR774677 = b07 / (b04+ eps)
  PSSRc1 = b08 / (b02+ eps)
  SR8002170 = b08 / (b12+ eps)
  SR860550 = b8a / (b03+ eps)
  SR860708 = b8a / (b05+ eps)
  SRMIRRed = b12 / (b04+ eps)
  SWIRI = 0.887; SRSWIRINIR = SWIRI / (b08+ eps)
  a = 0.064; b = 0.918; SAVI2 = b08 / (b04 + b / a)
  y = 0.735; Rr = 0.740; L = 0.487; RB = 0.560; SARVI = (1.0 + L) * (b08 - (Rr - y * (RB - Rr))) / (b08 + -(Rr - y * (RB - Rr)) + L)
  SLAVI = b08 / (b04 + b12+ eps)
  SQRT_ = np.sqrt(b08 / b04+ eps)
  SIPI_ = (b08 - b01) / (b08 - b04+ eps)
  GVIMSS = -0.283 * b03 - 0.66 * b04 + 0.577 * b06 + 0.388 * b09
  NSIMSS = -0.016 * b03 + 0.131 * b04 - 0.425 * b06 + 0.882 * b09
  SBIMSS = 0.332 * b03 + 0.603 * b04 + 0.675 * b06 + 0.262 * b09
  GVI = -0.2848 * b02 - 0.2435 * b03 - 0.5436 * b04 + 0.7243 * b08 + 0.084 * b11 - 0.18 * b12
  WET = 0.1509 * b02 + 0.1973 * b03 + 0.3279 * b04 + 0.3406 * b08 - 0.7112 * b11 - 0.4572 * b12
  YVIMSS = -0.899 * b03 + 0.428 * b04 + 0.076 * b06 - 0.041 * b09
  X = 0.114; A = 0.824; B = 0.421; TSAVI = (B * (b08 - B * b04 - A)) / (b04 + B * (b08 - A) + X * (1.0 + np.power(B, 2.0))+ eps)
  a = 0.419; b = 0.787; TSAVI2 = (a * b08 - a * b04 - b) / (b04 + a * b08 - a * b+ eps)
  TVI_ = np.sqrt((((b04 - b03) / (b04 + b03+ eps))) + 0.5)
  TCI = 1.2 * (b05 - b03) - 1.5 * (b04 - b03) * np.sqrt(b05 / (b04+ eps))
  VARI700 = (b05 - 1.7 * b04 + 0.7 * b02) / (b05 + 2.3 * b04 - 1.3 * b02+ eps)
  a = 0.752; WDVI = b08 - a * b04
  EPIChlb = 0.0337 * np.power((b04 / (b03+ eps)), 1.8695)
  LAI_green = 5.405 * b8ab5 - 0.114

  return [MI, ARVI_, SIPI, RENDVI, MRESR, RYI, NDYI, DYI, ACI, AVI_, SI, BSI, SAVI, FIDET, MTCI_, NPCRI, S2REP, CCCI, MCARI, TCARI,\
          PVI, EVI, NDVI, BAI, NDSI, MRENDVI, NDVIre, CIre, NDMI, TNDVI, VDVI, NDVIc, TVI, EXG, PSRI, RDVI, RATIO1, RATIO2, RATIO3, RATIO4,\
          NDVI2, NDWI, NDRE, NDRE_, NDRE7, MSI, RECI, b7b5, b7b6, b8ab5, VARI, MTCI, ExBlue, WDRVI, GRNDVI, LCI, BNDVI, AFRI, aci, bai,\
          NLI, EVI2, ATSAVI, AFRI2100, ARI, AVI, ARVI, ARVI2, BWDRVI, BRI, CARI, CARI2, Chlgreen, CIgreen, Chlrededge, CVI, CI, CTVI, CRI550, CRI700,\
          Datt1, Datt4, Datt6, D678500, D800550, D800680, DVIMSS, EVI2_, EPI, Fe2, Fe3, Fo, GEMI, GVMI, Gossan, GARI, GLI, GOSAVI, GSAVI, GBNDVI,\
          H, IVI, IPVI, I, IR550, IR700, LWCI, LogR, Maccioni, mCRIG, mCRIRE, MVI, MGVI, MNSI, MSBI, MYVI, mND680, mARI, MCARI1, MCARI2,\
          MCARIMTVI2, MCARIOSAVI, mSR, MSRNirRed, MSAVI, MSAVIhyper, MTVI1, MTVI2, NormG, NormR, NormNIR, PPR, PVR, GNDVIhyper, OSAVI, PNDVI, PVI_, RARSa1, RARSa2, RARSa3,\
          RARSa4, RARSc3, RARSc4, RBNDVI, REIP1, REIP2, Rre, RSR, SAVImir, IF, SR440740, SR520670, SR700, SR735710, SR774677, PSSRc1, SR8002170, SR860550, SR860708, SRMIRRed,\
          SRSWIRINIR, SAVI2, SARVI, SLAVI, SQRT_, SIPI_, GVIMSS, NSIMSS, SBIMSS, GVI, WET, YVIMSS, TSAVI, TSAVI2, TVI_, TCI, VARI700, WDVI, MNDVI, EPIChlb, LAI_green]

# %% [markdown]
# # <font color="orange"> Best model for Afghanistan: Classification using Time Series of S1, S2 & L8

# %%
train_data_S1S2 = train_data_afghanistan_S1S2
test_data_S1S2 = test_data_afghanistan_S1S2
train_data_L8 = train_data_afghanistan_landsat
test_data_L8 = test_data_afghanistan_landsat

# %%
comb = train_data_S1S2.copy()

num_date = 12    # 12 month

vegs = Parallel(n_jobs=-1, verbose=2, backend="multiprocessing")(map(delayed(vegetation_index), [x for x in range(num_date)]))

data = {}
for i in range(num_date):
  for n,m in zip(spectral_indices, vegs[i]):
    data[f'PERIOD_{i}_{n}'] = m

vi_df = pd.DataFrame(data)

vi_df = vi_df.fillna(-999999).replace([np.inf, -np.inf], -999999)

indices_df = pd.merge(vi_df, comb, how = 'left', left_index=True, right_index=True)
indices_df.shape        # spectral indices: 181 * 12(months); main bands of S1 and S2: 15 * 12(months); ID,Lat,Lon,Target,index: 5
# Out:
# [Parallel(n_jobs=-1)]: Using backend MultiprocessingBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    1.1s finished
# (500, 2357)

# %%
comb = test_data_S1S2.copy()

num_date = 12

vegs = Parallel(n_jobs=-1, verbose=2, backend="multiprocessing")(map(delayed(vegetation_index), [x for x in range(num_date)]))

data_ = {}
for i in range(num_date):
  for n,m in zip(spectral_indices, vegs[i]):
    data_[f'PERIOD_{i}_{n}'] = m

vi_df_test = pd.DataFrame(data_)
vi_df_test = vi_df_test.fillna(-999999).replace([np.inf, -np.inf], -999999)

vi_df_test2 = pd.merge(vi_df_test, comb, how = 'left', left_index=True, right_index=True)
vi_df_test2.shape   # spectral indices: 181 * 12(months); main bands of S1 and S2: 15 * 12(months); ID,Lat,Lon,index: 4
# Out:
# [Parallel(n_jobs=-1)]: Using backend MultiprocessingBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    0.4s finished
# (500, 2356)

# %%
features = ['B1','B2','B3','B4','B5','B6','B7','B10','B11']
months = [f'{feat}_month{i}' for i in range(1,13) for feat in features]

df = train_data_L8
df_train = pd.DataFrame()
df_month = pd.DataFrame()

for month_num in range(1,13):

  df_month = df[months[(month_num-1)*len(features):month_num*len(features)]].copy()
  df_month.columns = [f"{feat}_month{month_num}" for feat in features]

  df_month[f'NDVI_month{month_num}'] = (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + df_month[f'B4_month{month_num}'])
  df_month[f'NDWI_month{month_num}'] = (df_month[f'B3_month{month_num}'] - df_month[f'B5_month{month_num}']) / (df_month[f'B3_month{month_num}'] + df_month[f'B5_month{month_num}'])
  df_month[f'EVI_month{month_num}'] = 2.5 * (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + 6 * df_month[f'B4_month{month_num}'] - 7.5 * df_month[f'B2_month{month_num}'] + 1)
  df_month[f'BUI_month{month_num}'] = (df_month[f'B6_month{month_num}'] + df_month[f'B5_month{month_num}']) - (df_month[f'B4_month{month_num}'] + df_month[f'B3_month{month_num}'])
  df_month[f'NDBI_month{month_num}'] = (df_month[f'B6_month{month_num}'] - df_month[f'B5_month{month_num}']) / (df_month[f'B6_month{month_num}'] + df_month[f'B5_month{month_num}'])
  df_month[f'NDSI_month{month_num}'] = (df_month[f'B3_month{month_num}'] - df_month[f'B6_month{month_num}']) / (df_month[f'B3_month{month_num}'] + df_month[f'B6_month{month_num}'])
  df_month[f'SAVI_month{month_num}'] = (1 + 0.5) * (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + df_month[f'B4_month{month_num}'] + 0.5)

  df_train = pd.concat([df_train, df_month], axis=1)

df = test_data_L8
df_test = pd.DataFrame()
df_month = pd.DataFrame()

for month_num in range(1,13):

  df_month = df[months[(month_num-1)*len(features):month_num*len(features)]].copy()
  df_month.columns = [f"{feat}_month{month_num}" for feat in features]

  df_month[f'NDVI_month{month_num}'] = (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + df_month[f'B4_month{month_num}'])
  df_month[f'NDWI_month{month_num}'] = (df_month[f'B3_month{month_num}'] - df_month[f'B5_month{month_num}']) / (df_month[f'B3_month{month_num}'] + df_month[f'B5_month{month_num}'])
  df_month[f'EVI_month{month_num}'] = 2.5 * (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + 6 * df_month[f'B4_month{month_num}'] - 7.5 * df_month[f'B2_month{month_num}'] + 1)
  df_month[f'BUI_month{month_num}'] = (df_month[f'B6_month{month_num}'] + df_month[f'B5_month{month_num}']) - (df_month[f'B4_month{month_num}'] + df_month[f'B3_month{month_num}'])
  df_month[f'NDBI_month{month_num}'] = (df_month[f'B6_month{month_num}'] - df_month[f'B5_month{month_num}']) / (df_month[f'B6_month{month_num}'] + df_month[f'B5_month{month_num}'])
  df_month[f'NDSI_month{month_num}'] = (df_month[f'B3_month{month_num}'] - df_month[f'B6_month{month_num}']) / (df_month[f'B3_month{month_num}'] + df_month[f'B6_month{month_num}'])
  df_month[f'SAVI_month{month_num}'] = (1 + 0.5) * (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + df_month[f'B4_month{month_num}'] + 0.5)

  df_test = pd.concat([df_test, df_month], axis=1)

# %%
indices_df = pd.merge(indices_df, df_train, how = 'left', left_index=True, right_index=True)
vi_df_test2 = pd.merge(vi_df_test2, df_test, how = 'left', left_index=True, right_index=True)

# %%
s_train = indices_df.drop(['index', 'ID', 'Lat',	'Lon', 'Target'], axis=1)
target_season = indices_df['Target']
s_test = vi_df_test2.drop(['index', 'ID', 'Lat',	'Lon'], axis=1)

# %%
X = s_train.copy()
y = target_season.copy()
tess_ = s_test.copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=SEED)

# %%
# Best model for afghanistan
CAT = CatBoostClassifier(iterations=200, learning_rate=0.02, depth=6, bagging_temperature = 0.3, random_seed=SEED)

# %%
model = CAT
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f'Accuracy Score: {accuracy_score(y_test, y_pred)}')
print('LOSS: ', log_loss(y_test, y_pred))
# Out:
# 0:	learn: 0.6781142	total: 1.95s	remaining: 6m 28s
# 1:	learn: 0.6630806	total: 3.11s	remaining: 5m 8s
# 2:	learn: 0.6498568	total: 4.21s	remaining: 4m 36s
# 3:	learn: 0.6369495	total: 5.22s	remaining: 4m 15s
# 4:	learn: 0.6256818	total: 5.85s	remaining: 3m 48s
# 5:	learn: 0.6144142	total: 6.47s	remaining: 3m 29s
# 6:	learn: 0.6004344	total: 7.09s	remaining: 3m 15s
# 7:	learn: 0.5914356	total: 7.7s	remaining: 3m 4s
# 8:	learn: 0.5798303	total: 8.3s	remaining: 2m 56s
# 9:	learn: 0.5700620	total: 8.9s	remaining: 2m 49s
# 10:	learn: 0.5572733	total: 9.49s	remaining: 2m 43s
# 11:	learn: 0.5468446	total: 10.1s	remaining: 2m 38s
# 12:	learn: 0.5361706	total: 10.7s	remaining: 2m 34s
# 13:	learn: 0.5257546	total: 11.3s	remaining: 2m 30s
# 14:	learn: 0.5169410	total: 12s	remaining: 2m 27s
# 15:	learn: 0.5055321	total: 12.6s	remaining: 2m 24s
# 16:	learn: 0.4969926	total: 13.2s	remaining: 2m 21s
# 17:	learn: 0.4853408	total: 13.8s	remaining: 2m 19s
# 18:	learn: 0.4765554	total: 14.4s	remaining: 2m 17s
# 19:	learn: 0.4670180	total: 15s	remaining: 2m 15s
# 20:	learn: 0.4582229	total: 15.9s	remaining: 2m 15s
# 21:	learn: 0.4495476	total: 17.1s	remaining: 2m 18s
# 22:	learn: 0.4422465	total: 18.2s	remaining: 2m 19s
# 23:	learn: 0.4335440	total: 19.3s	remaining: 2m 21s
# 24:	learn: 0.4261045	total: 20.1s	remaining: 2m 20s
# 25:	learn: 0.4190314	total: 20.7s	remaining: 2m 18s
# 26:	learn: 0.4138412	total: 21.3s	remaining: 2m 16s
# 27:	learn: 0.4087698	total: 21.9s	remaining: 2m 14s
# 28:	learn: 0.4015377	total: 22.5s	remaining: 2m 12s
# 29:	learn: 0.3950222	total: 23.1s	remaining: 2m 10s
# 30:	learn: 0.3907718	total: 23.8s	remaining: 2m 9s
# 31:	learn: 0.3850955	total: 24.4s	remaining: 2m 7s
# 32:	learn: 0.3796016	total: 25s	remaining: 2m 6s
# 33:	learn: 0.3745708	total: 25.6s	remaining: 2m 4s
# 34:	learn: 0.3696393	total: 26.2s	remaining: 2m 3s
# 35:	learn: 0.3646424	total: 26.8s	remaining: 2m 2s
# 36:	learn: 0.3601290	total: 27.4s	remaining: 2m
# 37:	learn: 0.3560719	total: 28s	remaining: 1m 59s
# 38:	learn: 0.3510931	total: 28.6s	remaining: 1m 58s
# 39:	learn: 0.3468713	total: 29.3s	remaining: 1m 57s
# 40:	learn: 0.3421841	total: 29.9s	remaining: 1m 56s
# 41:	learn: 0.3379885	total: 31s	remaining: 1m 56s
# 42:	learn: 0.3338405	total: 32.2s	remaining: 1m 57s
# 43:	learn: 0.3292821	total: 33.2s	remaining: 1m 57s
# 44:	learn: 0.3257784	total: 34.3s	remaining: 1m 58s
# 45:	learn: 0.3199942	total: 34.9s	remaining: 1m 56s
# 46:	learn: 0.3152244	total: 35.5s	remaining: 1m 55s
# 47:	learn: 0.3116811	total: 36.1s	remaining: 1m 54s
# 48:	learn: 0.3069913	total: 36.7s	remaining: 1m 53s
# 49:	learn: 0.3024098	total: 37.3s	remaining: 1m 51s
# 50:	learn: 0.2984275	total: 37.9s	remaining: 1m 50s
# 51:	learn: 0.2946416	total: 38.5s	remaining: 1m 49s
# 52:	learn: 0.2908391	total: 39.1s	remaining: 1m 48s
# 53:	learn: 0.2868387	total: 39.7s	remaining: 1m 47s
# 54:	learn: 0.2836121	total: 40.4s	remaining: 1m 46s
# 55:	learn: 0.2805587	total: 41s	remaining: 1m 45s
# 56:	learn: 0.2774533	total: 41.6s	remaining: 1m 44s
# 57:	learn: 0.2745140	total: 42.2s	remaining: 1m 43s
# 58:	learn: 0.2715796	total: 42.8s	remaining: 1m 42s
# 59:	learn: 0.2682774	total: 43.4s	remaining: 1m 41s
# 60:	learn: 0.2657257	total: 44s	remaining: 1m 40s
# 61:	learn: 0.2633652	total: 45s	remaining: 1m 40s
# 62:	learn: 0.2603732	total: 46.1s	remaining: 1m 40s
# 63:	learn: 0.2583419	total: 47.2s	remaining: 1m 40s
# 64:	learn: 0.2558426	total: 48.3s	remaining: 1m 40s
# 65:	learn: 0.2532973	total: 49s	remaining: 1m 39s
# 66:	learn: 0.2500664	total: 49.6s	remaining: 1m 38s
# 67:	learn: 0.2482292	total: 50.2s	remaining: 1m 37s
# 68:	learn: 0.2457726	total: 50.8s	remaining: 1m 36s
# 69:	learn: 0.2438687	total: 51.4s	remaining: 1m 35s
# 70:	learn: 0.2409913	total: 52s	remaining: 1m 34s
# 71:	learn: 0.2386396	total: 52.6s	remaining: 1m 33s
# 72:	learn: 0.2359390	total: 53.5s	remaining: 1m 33s
# 73:	learn: 0.2339640	total: 54.6s	remaining: 1m 33s
# 74:	learn: 0.2319785	total: 55.7s	remaining: 1m 32s
# 75:	learn: 0.2304710	total: 56.8s	remaining: 1m 32s
# 76:	learn: 0.2281981	total: 57.7s	remaining: 1m 32s
# 77:	learn: 0.2259935	total: 58.2s	remaining: 1m 31s
# 78:	learn: 0.2249241	total: 59s	remaining: 1m 30s
# 79:	learn: 0.2228497	total: 1m	remaining: 1m 30s
# 80:	learn: 0.2207543	total: 1m 1s	remaining: 1m 30s
# 81:	learn: 0.2185589	total: 1m 2s	remaining: 1m 29s
# 82:	learn: 0.2165185	total: 1m 3s	remaining: 1m 29s
# 83:	learn: 0.2151710	total: 1m 3s	remaining: 1m 28s
# 84:	learn: 0.2135286	total: 1m 4s	remaining: 1m 27s
# 85:	learn: 0.2115395	total: 1m 5s	remaining: 1m 26s
# 86:	learn: 0.2096344	total: 1m 5s	remaining: 1m 25s
# 87:	learn: 0.2079223	total: 1m 6s	remaining: 1m 24s
# 88:	learn: 0.2061986	total: 1m 6s	remaining: 1m 23s
# 89:	learn: 0.2045725	total: 1m 7s	remaining: 1m 22s
# 90:	learn: 0.2027699	total: 1m 8s	remaining: 1m 21s
# 91:	learn: 0.2015405	total: 1m 8s	remaining: 1m 20s
# 92:	learn: 0.2002068	total: 1m 9s	remaining: 1m 19s
# 93:	learn: 0.1988257	total: 1m 9s	remaining: 1m 18s
# 94:	learn: 0.1969048	total: 1m 10s	remaining: 1m 17s
# 95:	learn: 0.1951359	total: 1m 11s	remaining: 1m 17s
# 96:	learn: 0.1933229	total: 1m 11s	remaining: 1m 16s
# 97:	learn: 0.1913562	total: 1m 12s	remaining: 1m 15s
# 98:	learn: 0.1897794	total: 1m 13s	remaining: 1m 14s
# 99:	learn: 0.1879570	total: 1m 14s	remaining: 1m 14s
# 100:	learn: 0.1865577	total: 1m 15s	remaining: 1m 13s
# 101:	learn: 0.1853991	total: 1m 16s	remaining: 1m 13s
# 102:	learn: 0.1845802	total: 1m 17s	remaining: 1m 12s
# 103:	learn: 0.1835228	total: 1m 18s	remaining: 1m 12s
# 104:	learn: 0.1814829	total: 1m 18s	remaining: 1m 11s
# 105:	learn: 0.1799240	total: 1m 19s	remaining: 1m 10s
# 106:	learn: 0.1784413	total: 1m 19s	remaining: 1m 9s
# 107:	learn: 0.1772328	total: 1m 20s	remaining: 1m 8s
# 108:	learn: 0.1754693	total: 1m 21s	remaining: 1m 7s
# 109:	learn: 0.1739032	total: 1m 21s	remaining: 1m 6s
# 110:	learn: 0.1725063	total: 1m 22s	remaining: 1m 6s
# 111:	learn: 0.1715933	total: 1m 22s	remaining: 1m 5s
# 112:	learn: 0.1698290	total: 1m 23s	remaining: 1m 4s
# 113:	learn: 0.1687945	total: 1m 24s	remaining: 1m 3s
# 114:	learn: 0.1676059	total: 1m 24s	remaining: 1m 2s
# 115:	learn: 0.1667648	total: 1m 25s	remaining: 1m 1s
# 116:	learn: 0.1656595	total: 1m 26s	remaining: 1m 1s
# 117:	learn: 0.1648296	total: 1m 26s	remaining: 1m
# 118:	learn: 0.1634154	total: 1m 27s	remaining: 59.4s
# 119:	learn: 0.1615924	total: 1m 28s	remaining: 58.8s
# 120:	learn: 0.1603418	total: 1m 29s	remaining: 58.3s
# 121:	learn: 0.1594986	total: 1m 30s	remaining: 57.8s
# 122:	learn: 0.1581955	total: 1m 31s	remaining: 57.3s
# 123:	learn: 0.1569510	total: 1m 32s	remaining: 56.6s
# 124:	learn: 0.1556798	total: 1m 32s	remaining: 55.7s
# 125:	learn: 0.1553534	total: 1m 33s	remaining: 54.9s
# 126:	learn: 0.1540367	total: 1m 34s	remaining: 54.1s
# 127:	learn: 0.1531022	total: 1m 34s	remaining: 53.3s
# 128:	learn: 0.1523233	total: 1m 35s	remaining: 52.4s
# 129:	learn: 0.1513454	total: 1m 35s	remaining: 51.6s
# 130:	learn: 0.1503045	total: 1m 36s	remaining: 50.8s
# 131:	learn: 0.1492684	total: 1m 37s	remaining: 50s
# 132:	learn: 0.1481425	total: 1m 37s	remaining: 49.2s
# 133:	learn: 0.1477160	total: 1m 38s	remaining: 48.4s
# 134:	learn: 0.1469456	total: 1m 38s	remaining: 47.6s
# 135:	learn: 0.1457774	total: 1m 39s	remaining: 46.8s
# 136:	learn: 0.1446288	total: 1m 40s	remaining: 46s
# 137:	learn: 0.1442428	total: 1m 40s	remaining: 45.3s
# 138:	learn: 0.1431139	total: 1m 41s	remaining: 44.5s
# 139:	learn: 0.1422883	total: 1m 41s	remaining: 43.7s
# 140:	learn: 0.1413186	total: 1m 42s	remaining: 43.1s
# 141:	learn: 0.1404412	total: 1m 44s	remaining: 42.5s
# 142:	learn: 0.1397691	total: 1m 45s	remaining: 42s
# 143:	learn: 0.1387641	total: 1m 46s	remaining: 41.4s
# 144:	learn: 0.1375642	total: 1m 46s	remaining: 40.6s
# 145:	learn: 0.1370589	total: 1m 47s	remaining: 39.8s
# 146:	learn: 0.1359159	total: 1m 48s	remaining: 39s
# 147:	learn: 0.1352959	total: 1m 48s	remaining: 38.2s
# 148:	learn: 0.1347151	total: 1m 49s	remaining: 37.4s
# 149:	learn: 0.1338445	total: 1m 49s	remaining: 36.7s
# 150:	learn: 0.1329375	total: 1m 50s	remaining: 35.9s
# 151:	learn: 0.1323671	total: 1m 51s	remaining: 35.1s
# 152:	learn: 0.1314400	total: 1m 51s	remaining: 34.3s
# 153:	learn: 0.1306806	total: 1m 52s	remaining: 33.6s
# 154:	learn: 0.1297087	total: 1m 52s	remaining: 32.8s
# 155:	learn: 0.1290251	total: 1m 53s	remaining: 32s
# 156:	learn: 0.1288204	total: 1m 54s	remaining: 31.3s
# 157:	learn: 0.1282890	total: 1m 54s	remaining: 30.5s
# 158:	learn: 0.1281113	total: 1m 55s	remaining: 29.8s
# 159:	learn: 0.1274193	total: 1m 56s	remaining: 29s
# 160:	learn: 0.1268568	total: 1m 56s	remaining: 28.3s
# 161:	learn: 0.1262673	total: 1m 58s	remaining: 27.7s
# 162:	learn: 0.1256193	total: 1m 59s	remaining: 27s
# 163:	learn: 0.1248640	total: 2m	remaining: 26.4s
# 164:	learn: 0.1240810	total: 2m 1s	remaining: 25.7s
# 165:	learn: 0.1238008	total: 2m 1s	remaining: 24.9s
# 166:	learn: 0.1231597	total: 2m 2s	remaining: 24.2s
# 167:	learn: 0.1229374	total: 2m 2s	remaining: 23.4s
# 168:	learn: 0.1220556	total: 2m 3s	remaining: 22.6s
# 169:	learn: 0.1211287	total: 2m 4s	remaining: 21.9s
# 170:	learn: 0.1207167	total: 2m 4s	remaining: 21.1s
# 171:	learn: 0.1202852	total: 2m 5s	remaining: 20.4s
# 172:	learn: 0.1198665	total: 2m 5s	remaining: 19.7s
# 173:	learn: 0.1195448	total: 2m 6s	remaining: 18.9s
# 174:	learn: 0.1190877	total: 2m 7s	remaining: 18.2s
# 175:	learn: 0.1184491	total: 2m 7s	remaining: 17.4s
# 176:	learn: 0.1179956	total: 2m 8s	remaining: 16.7s
# 177:	learn: 0.1176942	total: 2m 8s	remaining: 15.9s
# 178:	learn: 0.1172800	total: 2m 9s	remaining: 15.2s
# 179:	learn: 0.1166038	total: 2m 10s	remaining: 14.5s
# 180:	learn: 0.1160952	total: 2m 10s	remaining: 13.7s
# 181:	learn: 0.1153237	total: 2m 12s	remaining: 13.1s
# 182:	learn: 0.1145203	total: 2m 13s	remaining: 12.4s
# 183:	learn: 0.1142628	total: 2m 14s	remaining: 11.7s
# 184:	learn: 0.1135792	total: 2m 15s	remaining: 11s
# 185:	learn: 0.1131674	total: 2m 15s	remaining: 10.2s
# 186:	learn: 0.1123737	total: 2m 16s	remaining: 9.48s
# 187:	learn: 0.1119979	total: 2m 17s	remaining: 8.75s
# 188:	learn: 0.1115987	total: 2m 17s	remaining: 8.01s
# 189:	learn: 0.1110577	total: 2m 18s	remaining: 7.28s
# 190:	learn: 0.1104767	total: 2m 18s	remaining: 6.54s
# 191:	learn: 0.1102570	total: 2m 19s	remaining: 5.81s
# 192:	learn: 0.1097135	total: 2m 20s	remaining: 5.08s
# 193:	learn: 0.1091687	total: 2m 20s	remaining: 4.35s
# 194:	learn: 0.1082953	total: 2m 21s	remaining: 3.62s
# 195:	learn: 0.1075667	total: 2m 21s	remaining: 2.9s
# 196:	learn: 0.1067334	total: 2m 22s	remaining: 2.17s
# 197:	learn: 0.1062066	total: 2m 23s	remaining: 1.45s
# 198:	learn: 0.1054642	total: 2m 23s	remaining: 722ms
# 199:	learn: 0.1049410	total: 2m 24s	remaining: 0us
# Accuracy Score: 0.86
# LOSS:  5.046111474476402

# %%
predictions = model.predict(tess_)
sub_file = pd.DataFrame({'ID': test_data_S1S2.ID, 'Target': predictions})
sub_file.to_csv('afghanistan.csv', index = False)

# %% [markdown]
# # <font color="orange"> Best model for Sudan: Classification using Time Series of S1, S2 & L8

# %%
train_data_S1S2 = train_data_sudan_S1S2
test_data_S1S2 = test_data_sudan_S1S2
train_data_L8 = train_data_sudan_landsat
test_data_L8 = test_data_sudan_landsat

# %%
comb = train_data_S1S2.copy()

num_date = 12    # 12 month

vegs = Parallel(n_jobs=-1, verbose=2, backend="multiprocessing")(map(delayed(vegetation_index), [x for x in range(num_date)]))

data = {}
for i in range(num_date):
  for n,m in zip(spectral_indices, vegs[i]):
    data[f'PERIOD_{i}_{n}'] = m

vi_df = pd.DataFrame(data)

vi_df = vi_df.fillna(-999999).replace([np.inf, -np.inf], -999999)
indices_df = pd.merge(vi_df, comb, how = 'left', left_index=True, right_index=True)
indices_df.shape   # spectral indices: 181 * 12(months); main bands of S1 and S2: 14 * 12(months); ID,Lat,Lon,Target,index: 5
# Out:
# [Parallel(n_jobs=-1)]: Using backend MultiprocessingBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    0.4s finished
# (500, 2345)

# %%
comb = test_data_S1S2.copy()

num_date = 12

vegs = Parallel(n_jobs=-1, verbose=2, backend="multiprocessing")(map(delayed(vegetation_index), [x for x in range(num_date)]))

data_ = {}
for i in range(num_date):
  for n,m in zip(spectral_indices, vegs[i]):
    data_[f'PERIOD_{i}_{n}'] = m

vi_df_test = pd.DataFrame(data_)
vi_df_test = vi_df_test.fillna(-999999).replace([np.inf, -np.inf], -999999)
vi_df_test2 = pd.merge(vi_df_test, comb, how = 'left', left_index=True, right_index=True)
vi_df_test2.shape   # spectral indices: 181 * 12(months); main bands of S1 and S2: 14 * 12(months); ID,Lat,Lon,index: 4
# Out:
# [Parallel(n_jobs=-1)]: Using backend MultiprocessingBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    0.4s finished
# (500, 2344)

# %%
features = ['B1','B2','B3','B4','B5','B6','B7','B10','B11']
months = [f'{feat}_month{i}' for i in range(1,13) for feat in features]

df = train_data_L8
df_train = pd.DataFrame()
df_month = pd.DataFrame()

for month_num in range(1,13):

  df_month = df[months[(month_num-1)*len(features):month_num*len(features)]].copy()
  df_month.columns = [f"{feat}_month{month_num}" for feat in features]

  df_month[f'NDVI_month{month_num}'] = (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + df_month[f'B4_month{month_num}'])
  df_month[f'NDWI_month{month_num}'] = (df_month[f'B3_month{month_num}'] - df_month[f'B5_month{month_num}']) / (df_month[f'B3_month{month_num}'] + df_month[f'B5_month{month_num}'])
  df_month[f'EVI_month{month_num}'] = 2.5 * (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + 6 * df_month[f'B4_month{month_num}'] - 7.5 * df_month[f'B2_month{month_num}'] + 1)
  df_month[f'BUI_month{month_num}'] = (df_month[f'B6_month{month_num}'] + df_month[f'B5_month{month_num}']) - (df_month[f'B4_month{month_num}'] + df_month[f'B3_month{month_num}'])
  df_month[f'NDBI_month{month_num}'] = (df_month[f'B6_month{month_num}'] - df_month[f'B5_month{month_num}']) / (df_month[f'B6_month{month_num}'] + df_month[f'B5_month{month_num}'])
  df_month[f'NDSI_month{month_num}'] = (df_month[f'B3_month{month_num}'] - df_month[f'B6_month{month_num}']) / (df_month[f'B3_month{month_num}'] + df_month[f'B6_month{month_num}'])
  df_month[f'SAVI_month{month_num}'] = (1 + 0.5) * (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + df_month[f'B4_month{month_num}'] + 0.5)

  df_train = pd.concat([df_train, df_month], axis=1)

df = test_data_L8
df_test = pd.DataFrame()
df_month = pd.DataFrame()

for month_num in range(1,13):

  df_month = df[months[(month_num-1)*len(features):month_num*len(features)]].copy()
  df_month.columns = [f"{feat}_month{month_num}" for feat in features]

  df_month[f'NDVI_month{month_num}'] = (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + df_month[f'B4_month{month_num}'])
  df_month[f'NDWI_month{month_num}'] = (df_month[f'B3_month{month_num}'] - df_month[f'B5_month{month_num}']) / (df_month[f'B3_month{month_num}'] + df_month[f'B5_month{month_num}'])
  df_month[f'EVI_month{month_num}'] = 2.5 * (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + 6 * df_month[f'B4_month{month_num}'] - 7.5 * df_month[f'B2_month{month_num}'] + 1)
  df_month[f'BUI_month{month_num}'] = (df_month[f'B6_month{month_num}'] + df_month[f'B5_month{month_num}']) - (df_month[f'B4_month{month_num}'] + df_month[f'B3_month{month_num}'])
  df_month[f'NDBI_month{month_num}'] = (df_month[f'B6_month{month_num}'] - df_month[f'B5_month{month_num}']) / (df_month[f'B6_month{month_num}'] + df_month[f'B5_month{month_num}'])
  df_month[f'NDSI_month{month_num}'] = (df_month[f'B3_month{month_num}'] - df_month[f'B6_month{month_num}']) / (df_month[f'B3_month{month_num}'] + df_month[f'B6_month{month_num}'])
  df_month[f'SAVI_month{month_num}'] = (1 + 0.5) * (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + df_month[f'B4_month{month_num}'] + 0.5)

  df_test = pd.concat([df_test, df_month], axis=1)

# %%
indices_df = pd.merge(indices_df, df_train, how = 'left', left_index=True, right_index=True)
vi_df_test2 = pd.merge(vi_df_test2, df_test, how = 'left', left_index=True, right_index=True)

s_train = indices_df.drop(['index', 'ID', 'Lat',	'Lon', 'Target'], axis=1)
target_season = indices_df['Target']
s_test = vi_df_test2.drop(['index', 'ID', 'Lat',	'Lon'], axis=1)

# %%
X = s_train.copy()
y = target_season.copy()
tess_ = s_test.copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=SEED)

# %%
# Best model for Sudan
CAT = CatBoostClassifier(iterations=200, learning_rate=0.02, depth=6, bagging_temperature = 0.3, random_seed=SEED)

# %%
model = CAT
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f'Accuracy Score: {accuracy_score(y_test, y_pred)}')
print('LOSS: ', log_loss(y_test, y_pred))
# Out:
# 0:	learn: 0.6705449	total: 837ms	remaining: 2m 46s
# 1:	learn: 0.6434977	total: 1.44s	remaining: 2m 22s
# 2:	learn: 0.6190199	total: 2.07s	remaining: 2m 15s
# 3:	learn: 0.5915477	total: 2.67s	remaining: 2m 10s
# 4:	learn: 0.5707429	total: 3.28s	remaining: 2m 7s
# 5:	learn: 0.5492892	total: 3.89s	remaining: 2m 5s
# 6:	learn: 0.5286369	total: 4.5s	remaining: 2m 4s
# 7:	learn: 0.5097023	total: 5.11s	remaining: 2m 2s
# 8:	learn: 0.4914133	total: 5.72s	remaining: 2m 1s
# 9:	learn: 0.4700387	total: 6.32s	remaining: 2m
# 10:	learn: 0.4542614	total: 6.91s	remaining: 1m 58s
# 11:	learn: 0.4367108	total: 7.5s	remaining: 1m 57s
# 12:	learn: 0.4213186	total: 8.57s	remaining: 2m 3s
# 13:	learn: 0.4041178	total: 9.71s	remaining: 2m 8s
# 14:	learn: 0.3832322	total: 10.8s	remaining: 2m 13s
# 15:	learn: 0.3693160	total: 11.9s	remaining: 2m 17s
# 16:	learn: 0.3554939	total: 12.5s	remaining: 2m 14s
# 17:	learn: 0.3416643	total: 13.1s	remaining: 2m 12s
# 18:	learn: 0.3306947	total: 13.7s	remaining: 2m 10s
# 19:	learn: 0.3187391	total: 14.3s	remaining: 2m 8s
# 20:	learn: 0.3071974	total: 14.9s	remaining: 2m 7s
# 21:	learn: 0.2966712	total: 15.5s	remaining: 2m 5s
# 22:	learn: 0.2877866	total: 16.1s	remaining: 2m 4s
# 23:	learn: 0.2802131	total: 16.7s	remaining: 2m 2s
# 24:	learn: 0.2698895	total: 17.3s	remaining: 2m 1s
# 25:	learn: 0.2599728	total: 17.9s	remaining: 2m
# 26:	learn: 0.2520001	total: 18.6s	remaining: 1m 58s
# 27:	learn: 0.2446793	total: 19.1s	remaining: 1m 57s
# 28:	learn: 0.2361164	total: 19.8s	remaining: 1m 56s
# 29:	learn: 0.2285811	total: 20.4s	remaining: 1m 55s
# 30:	learn: 0.2202594	total: 20.9s	remaining: 1m 54s
# 31:	learn: 0.2124119	total: 21.6s	remaining: 1m 53s
# 32:	learn: 0.2062010	total: 22.3s	remaining: 1m 52s
# 33:	learn: 0.2003515	total: 23.4s	remaining: 1m 54s
# 34:	learn: 0.1944655	total: 24.4s	remaining: 1m 55s
# 35:	learn: 0.1887211	total: 25.6s	remaining: 1m 56s
# 36:	learn: 0.1823451	total: 26.5s	remaining: 1m 56s
# 37:	learn: 0.1777027	total: 27.1s	remaining: 1m 55s
# 38:	learn: 0.1738197	total: 27.7s	remaining: 1m 54s
# 39:	learn: 0.1679331	total: 28.3s	remaining: 1m 53s
# 40:	learn: 0.1631765	total: 28.9s	remaining: 1m 52s
# 41:	learn: 0.1586868	total: 29.5s	remaining: 1m 50s
# 42:	learn: 0.1543707	total: 30.1s	remaining: 1m 49s
# 43:	learn: 0.1492753	total: 30.7s	remaining: 1m 48s
# 44:	learn: 0.1450178	total: 31.3s	remaining: 1m 47s
# 45:	learn: 0.1408900	total: 31.9s	remaining: 1m 46s
# 46:	learn: 0.1371149	total: 32.5s	remaining: 1m 45s
# 47:	learn: 0.1344219	total: 33.1s	remaining: 1m 44s
# 48:	learn: 0.1309874	total: 33.7s	remaining: 1m 43s
# 49:	learn: 0.1276959	total: 34.3s	remaining: 1m 42s
# 50:	learn: 0.1241633	total: 34.9s	remaining: 1m 42s
# 51:	learn: 0.1200622	total: 35.5s	remaining: 1m 41s
# 52:	learn: 0.1174598	total: 36.1s	remaining: 1m 40s
# 53:	learn: 0.1145099	total: 37s	remaining: 1m 40s
# 54:	learn: 0.1121142	total: 38.2s	remaining: 1m 40s
# 55:	learn: 0.1092497	total: 39.3s	remaining: 1m 41s
# 56:	learn: 0.1068313	total: 40.4s	remaining: 1m 41s
# 57:	learn: 0.1044244	total: 41.2s	remaining: 1m 40s
# 58:	learn: 0.1018162	total: 41.8s	remaining: 1m 39s
# 59:	learn: 0.0998830	total: 42.4s	remaining: 1m 38s
# 60:	learn: 0.0978057	total: 43s	remaining: 1m 37s
# 61:	learn: 0.0957066	total: 43.6s	remaining: 1m 36s
# 62:	learn: 0.0938596	total: 44.2s	remaining: 1m 36s
# 63:	learn: 0.0918277	total: 44.8s	remaining: 1m 35s
# 64:	learn: 0.0898591	total: 45.4s	remaining: 1m 34s
# 65:	learn: 0.0875782	total: 46s	remaining: 1m 33s
# 66:	learn: 0.0858706	total: 46.6s	remaining: 1m 32s
# 67:	learn: 0.0840692	total: 47.2s	remaining: 1m 31s
# 68:	learn: 0.0822564	total: 47.8s	remaining: 1m 30s
# 69:	learn: 0.0812219	total: 48.4s	remaining: 1m 29s
# 70:	learn: 0.0795651	total: 49s	remaining: 1m 28s
# 71:	learn: 0.0774504	total: 49.6s	remaining: 1m 28s
# 72:	learn: 0.0757039	total: 50.2s	remaining: 1m 27s
# 73:	learn: 0.0740581	total: 50.8s	remaining: 1m 26s
# 74:	learn: 0.0726137	total: 51.9s	remaining: 1m 26s
# 75:	learn: 0.0710688	total: 53s	remaining: 1m 26s
# 76:	learn: 0.0694153	total: 54.1s	remaining: 1m 26s
# 77:	learn: 0.0680631	total: 55.2s	remaining: 1m 26s
# 78:	learn: 0.0670529	total: 55.8s	remaining: 1m 25s
# 79:	learn: 0.0657837	total: 56.3s	remaining: 1m 24s
# 80:	learn: 0.0645888	total: 57s	remaining: 1m 23s
# 81:	learn: 0.0630660	total: 57.6s	remaining: 1m 22s
# 82:	learn: 0.0615514	total: 58.2s	remaining: 1m 22s
# 83:	learn: 0.0601522	total: 58.8s	remaining: 1m 21s
# 84:	learn: 0.0591668	total: 59.4s	remaining: 1m 20s
# 85:	learn: 0.0581380	total: 60s	remaining: 1m 19s
# 86:	learn: 0.0569176	total: 1m	remaining: 1m 18s
# 87:	learn: 0.0559170	total: 1m 1s	remaining: 1m 17s
# 88:	learn: 0.0548715	total: 1m 1s	remaining: 1m 17s
# 89:	learn: 0.0538424	total: 1m 2s	remaining: 1m 16s
# 90:	learn: 0.0530686	total: 1m 2s	remaining: 1m 15s
# 91:	learn: 0.0520071	total: 1m 3s	remaining: 1m 14s
# 92:	learn: 0.0507737	total: 1m 4s	remaining: 1m 13s
# 93:	learn: 0.0497746	total: 1m 4s	remaining: 1m 13s
# 94:	learn: 0.0489010	total: 1m 5s	remaining: 1m 12s
# 95:	learn: 0.0480466	total: 1m 6s	remaining: 1m 12s
# 96:	learn: 0.0474093	total: 1m 7s	remaining: 1m 12s
# 97:	learn: 0.0465837	total: 1m 9s	remaining: 1m 11s
# 98:	learn: 0.0458236	total: 1m 9s	remaining: 1m 11s
# 99:	learn: 0.0451262	total: 1m 10s	remaining: 1m 10s
# 100:	learn: 0.0444308	total: 1m 11s	remaining: 1m 9s
# 101:	learn: 0.0435053	total: 1m 11s	remaining: 1m 8s
# 102:	learn: 0.0428937	total: 1m 12s	remaining: 1m 8s
# 103:	learn: 0.0422761	total: 1m 12s	remaining: 1m 7s
# 104:	learn: 0.0414505	total: 1m 13s	remaining: 1m 6s
# 105:	learn: 0.0408068	total: 1m 14s	remaining: 1m 5s
# 106:	learn: 0.0403287	total: 1m 14s	remaining: 1m 4s
# 107:	learn: 0.0398172	total: 1m 15s	remaining: 1m 4s
# 108:	learn: 0.0391221	total: 1m 15s	remaining: 1m 3s
# 109:	learn: 0.0384832	total: 1m 16s	remaining: 1m 2s
# 110:	learn: 0.0379618	total: 1m 17s	remaining: 1m 1s
# 111:	learn: 0.0373459	total: 1m 17s	remaining: 1m 1s
# 112:	learn: 0.0367925	total: 1m 18s	remaining: 1m
# 113:	learn: 0.0364000	total: 1m 18s	remaining: 59.5s
# 114:	learn: 0.0357653	total: 1m 19s	remaining: 58.7s
# 115:	learn: 0.0353050	total: 1m 20s	remaining: 58.3s
# 116:	learn: 0.0349666	total: 1m 21s	remaining: 57.9s
# 117:	learn: 0.0345184	total: 1m 22s	remaining: 57.5s
# 118:	learn: 0.0339141	total: 1m 23s	remaining: 57.1s
# 119:	learn: 0.0334235	total: 1m 25s	remaining: 56.7s
# 120:	learn: 0.0330241	total: 1m 25s	remaining: 56.1s
# 121:	learn: 0.0326026	total: 1m 27s	remaining: 55.7s
# 122:	learn: 0.0319959	total: 1m 28s	remaining: 55.2s
# 123:	learn: 0.0316401	total: 1m 28s	remaining: 54.5s
# 124:	learn: 0.0313017	total: 1m 29s	remaining: 53.7s
# 125:	learn: 0.0307917	total: 1m 30s	remaining: 52.9s
# 126:	learn: 0.0303479	total: 1m 30s	remaining: 52.1s
# 127:	learn: 0.0301071	total: 1m 31s	remaining: 51.4s
# 128:	learn: 0.0297183	total: 1m 31s	remaining: 50.6s
# 129:	learn: 0.0293453	total: 1m 32s	remaining: 49.8s
# 130:	learn: 0.0289543	total: 1m 33s	remaining: 49s
# 131:	learn: 0.0285866	total: 1m 33s	remaining: 48.3s
# 132:	learn: 0.0282257	total: 1m 34s	remaining: 47.5s
# 133:	learn: 0.0279880	total: 1m 34s	remaining: 46.8s
# 134:	learn: 0.0274847	total: 1m 36s	remaining: 46.2s
# 135:	learn: 0.0271796	total: 1m 37s	remaining: 45.7s
# 136:	learn: 0.0268902	total: 1m 38s	remaining: 45.2s
# 137:	learn: 0.0266153	total: 1m 39s	remaining: 44.6s
# 138:	learn: 0.0262888	total: 1m 39s	remaining: 43.9s
# 139:	learn: 0.0259662	total: 1m 40s	remaining: 43.1s
# 140:	learn: 0.0256385	total: 1m 41s	remaining: 42.3s
# 141:	learn: 0.0252596	total: 1m 41s	remaining: 41.6s
# 142:	learn: 0.0249491	total: 1m 42s	remaining: 40.8s
# 143:	learn: 0.0247519	total: 1m 42s	remaining: 40s
# 144:	learn: 0.0245416	total: 1m 43s	remaining: 39.3s
# 145:	learn: 0.0241981	total: 1m 44s	remaining: 38.5s
# 146:	learn: 0.0238517	total: 1m 44s	remaining: 37.8s
# 147:	learn: 0.0236212	total: 1m 45s	remaining: 37s
# 148:	learn: 0.0232441	total: 1m 45s	remaining: 36.3s
# 149:	learn: 0.0230034	total: 1m 46s	remaining: 35.5s
# 150:	learn: 0.0226452	total: 1m 47s	remaining: 34.8s
# 151:	learn: 0.0224284	total: 1m 47s	remaining: 34s
# 152:	learn: 0.0221491	total: 1m 48s	remaining: 33.3s
# 153:	learn: 0.0219026	total: 1m 48s	remaining: 32.5s
# 154:	learn: 0.0216839	total: 1m 49s	remaining: 31.8s
# 155:	learn: 0.0214327	total: 1m 50s	remaining: 31.2s
# 156:	learn: 0.0211148	total: 1m 51s	remaining: 30.6s
# 157:	learn: 0.0209452	total: 1m 52s	remaining: 30s
# 158:	learn: 0.0207448	total: 1m 53s	remaining: 29.4s
# 159:	learn: 0.0206257	total: 1m 54s	remaining: 28.6s
# 160:	learn: 0.0204555	total: 1m 55s	remaining: 27.9s
# 161:	learn: 0.0202061	total: 1m 55s	remaining: 27.1s
# 162:	learn: 0.0199911	total: 1m 56s	remaining: 26.4s
# 163:	learn: 0.0198261	total: 1m 56s	remaining: 25.7s
# 164:	learn: 0.0196645	total: 1m 57s	remaining: 24.9s
# 165:	learn: 0.0194598	total: 1m 58s	remaining: 24.2s
# 166:	learn: 0.0191969	total: 1m 58s	remaining: 23.4s
# 167:	learn: 0.0190065	total: 1m 59s	remaining: 22.7s
# 168:	learn: 0.0187363	total: 1m 59s	remaining: 22s
# 169:	learn: 0.0185137	total: 2m	remaining: 21.3s
# 170:	learn: 0.0183900	total: 2m 1s	remaining: 20.5s
# 171:	learn: 0.0182101	total: 2m 1s	remaining: 19.8s
# 172:	learn: 0.0180896	total: 2m 2s	remaining: 19.1s
# 173:	learn: 0.0179519	total: 2m 2s	remaining: 18.4s
# 174:	learn: 0.0177979	total: 2m 3s	remaining: 17.6s
# 175:	learn: 0.0176207	total: 2m 4s	remaining: 16.9s
# 176:	learn: 0.0174550	total: 2m 5s	remaining: 16.3s
# 177:	learn: 0.0172903	total: 2m 6s	remaining: 15.6s
# 178:	learn: 0.0171450	total: 2m 7s	remaining: 15s
# 179:	learn: 0.0169621	total: 2m 8s	remaining: 14.3s
# 180:	learn: 0.0168462	total: 2m 9s	remaining: 13.6s
# 181:	learn: 0.0167024	total: 2m 9s	remaining: 12.8s
# 182:	learn: 0.0165228	total: 2m 10s	remaining: 12.1s
# 183:	learn: 0.0163999	total: 2m 10s	remaining: 11.4s
# 184:	learn: 0.0162747	total: 2m 11s	remaining: 10.7s
# 185:	learn: 0.0161833	total: 2m 12s	remaining: 10s
# 186:	learn: 0.0160251	total: 2m 14s	remaining: 9.32s
# 187:	learn: 0.0159189	total: 2m 15s	remaining: 8.63s
# 188:	learn: 0.0158222	total: 2m 15s	remaining: 7.91s
# 189:	learn: 0.0157340	total: 2m 16s	remaining: 7.18s
# 190:	learn: 0.0156067	total: 2m 17s	remaining: 6.46s
# 191:	learn: 0.0154833	total: 2m 17s	remaining: 5.74s
# 192:	learn: 0.0153261	total: 2m 19s	remaining: 5.07s
# 193:	learn: 0.0152644	total: 2m 21s	remaining: 4.38s
# 194:	learn: 0.0151173	total: 2m 23s	remaining: 3.67s
# 195:	learn: 0.0149961	total: 2m 24s	remaining: 2.94s
# 196:	learn: 0.0148477	total: 2m 24s	remaining: 2.2s
# 197:	learn: 0.0147501	total: 2m 25s	remaining: 1.47s
# 198:	learn: 0.0146437	total: 2m 25s	remaining: 733ms
# 199:	learn: 0.0145282	total: 2m 26s	remaining: 0us
# Accuracy Score: 0.9933333333333333
# LOSS:  0.24029102259411456

# %%
predictions = model.predict(tess_)
sub_file = pd.DataFrame({'ID': test_data_S1S2.ID, 'Target': predictions})
sub_file.to_csv('sudan.csv', index = False)

# %% [markdown]
# # <font color="orange"> Best model for Iran: Classification using Time Series of S1, S2 & L8

# %%
train_data_S1S2 = train_data_iran_S1S2
test_data_S1S2 = test_data_iran_S1S2
train_data_L8 = train_data_iran_landsat
test_data_L8 = test_data_iran_landsat

# %%
comb = train_data_S1S2.copy()

num_date = 12    # 12 month

vegs = Parallel(n_jobs=-1, verbose=2, backend="multiprocessing")(map(delayed(vegetation_index), [x for x in range(num_date)]))

data = {}
for i in range(num_date):
  for n,m in zip(spectral_indices, vegs[i]):
    data[f'PERIOD_{i}_{n}'] = m

vi_df = pd.DataFrame(data)

vi_df = vi_df.fillna(-999999).replace([np.inf, -np.inf], -999999)

indices_df = pd.merge(vi_df, comb, how = 'left', left_index=True, right_index=True)
indices_df.shape        # spectral indices: 181 * 12(months); main bands of S1 and S2: 15 * 12(months); ID,Lat,Lon,Target,index: 5
# Out:
# [Parallel(n_jobs=-1)]: Using backend MultiprocessingBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    0.4s finished
# (500, 2357)

# %%
comb = test_data_S1S2.copy()

num_date = 12

vegs = Parallel(n_jobs=-1, verbose=2, backend="multiprocessing")(map(delayed(vegetation_index), [x for x in range(num_date)]))

data_ = {}
for i in range(num_date):
  for n,m in zip(spectral_indices, vegs[i]):
    data_[f'PERIOD_{i}_{n}'] = m

vi_df_test = pd.DataFrame(data_)
vi_df_test = vi_df_test.fillna(-999999).replace([np.inf, -np.inf], -999999)

vi_df_test2 = pd.merge(vi_df_test, comb, how = 'left', left_index=True, right_index=True)
vi_df_test2.shape   # spectral indices: 181 * 12(months); main bands of S1 and S2: 15 * 12(months); ID,Lat,Lon,index: 4
# Out:
# [Parallel(n_jobs=-1)]: Using backend MultiprocessingBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    0.4s finished
# (500, 2356)

# %%
features = ['B1','B2','B3','B4','B5','B6','B7','B10','B11']
months = [f'{feat}_month{i}' for i in range(1,13) for feat in features]

df = train_data_L8
df_train = pd.DataFrame()
df_month = pd.DataFrame()

for month_num in range(1,13):

  df_month = df[months[(month_num-1)*len(features):month_num*len(features)]].copy()
  df_month.columns = [f"{feat}_month{month_num}" for feat in features]

  df_month[f'NDVI_month{month_num}'] = (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + df_month[f'B4_month{month_num}'])
  df_month[f'NDWI_month{month_num}'] = (df_month[f'B3_month{month_num}'] - df_month[f'B5_month{month_num}']) / (df_month[f'B3_month{month_num}'] + df_month[f'B5_month{month_num}'])
  df_month[f'EVI_month{month_num}'] = 2.5 * (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + 6 * df_month[f'B4_month{month_num}'] - 7.5 * df_month[f'B2_month{month_num}'] + 1)
  df_month[f'BUI_month{month_num}'] = (df_month[f'B6_month{month_num}'] + df_month[f'B5_month{month_num}']) - (df_month[f'B4_month{month_num}'] + df_month[f'B3_month{month_num}'])
  df_month[f'NDBI_month{month_num}'] = (df_month[f'B6_month{month_num}'] - df_month[f'B5_month{month_num}']) / (df_month[f'B6_month{month_num}'] + df_month[f'B5_month{month_num}'])
  df_month[f'NDSI_month{month_num}'] = (df_month[f'B3_month{month_num}'] - df_month[f'B6_month{month_num}']) / (df_month[f'B3_month{month_num}'] + df_month[f'B6_month{month_num}'])
  df_month[f'SAVI_month{month_num}'] = (1 + 0.5) * (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + df_month[f'B4_month{month_num}'] + 0.5)

  df_train = pd.concat([df_train, df_month], axis=1)

df = test_data_L8
df_test = pd.DataFrame()
df_month = pd.DataFrame()

for month_num in range(1,13):

  df_month = df[months[(month_num-1)*len(features):month_num*len(features)]].copy()
  df_month.columns = [f"{feat}_month{month_num}" for feat in features]

  df_month[f'NDVI_month{month_num}'] = (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + df_month[f'B4_month{month_num}'])
  df_month[f'NDWI_month{month_num}'] = (df_month[f'B3_month{month_num}'] - df_month[f'B5_month{month_num}']) / (df_month[f'B3_month{month_num}'] + df_month[f'B5_month{month_num}'])
  df_month[f'EVI_month{month_num}'] = 2.5 * (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + 6 * df_month[f'B4_month{month_num}'] - 7.5 * df_month[f'B2_month{month_num}'] + 1)
  df_month[f'BUI_month{month_num}'] = (df_month[f'B6_month{month_num}'] + df_month[f'B5_month{month_num}']) - (df_month[f'B4_month{month_num}'] + df_month[f'B3_month{month_num}'])
  df_month[f'NDBI_month{month_num}'] = (df_month[f'B6_month{month_num}'] - df_month[f'B5_month{month_num}']) / (df_month[f'B6_month{month_num}'] + df_month[f'B5_month{month_num}'])
  df_month[f'NDSI_month{month_num}'] = (df_month[f'B3_month{month_num}'] - df_month[f'B6_month{month_num}']) / (df_month[f'B3_month{month_num}'] + df_month[f'B6_month{month_num}'])
  df_month[f'SAVI_month{month_num}'] = (1 + 0.5) * (df_month[f'B5_month{month_num}'] - df_month[f'B4_month{month_num}']) / (df_month[f'B5_month{month_num}'] + df_month[f'B4_month{month_num}'] + 0.5)

  df_test = pd.concat([df_test, df_month], axis=1)

# %%
indices_df = pd.merge(indices_df, df_train, how = 'left', left_index=True, right_index=True)
vi_df_test2 = pd.merge(vi_df_test2, df_test, how = 'left', left_index=True, right_index=True)

# %%
s_train = indices_df.drop(['index', 'ID', 'Lat',	'Lon', 'Target'], axis=1)
target_season = indices_df['Target']
s_test = vi_df_test2.drop(['index', 'ID', 'Lat',	'Lon'], axis=1)

# %%
X = s_train.copy()
y = target_season.copy()
tess_ = s_test.copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=SEED)

# %%
# Best model for Iran
CAT = CatBoostClassifier(iterations=500, learning_rate=0.04, depth=2, bagging_temperature = 0.3, random_seed=SEED)

# %%
model = CAT
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f'Accuracy Score: {accuracy_score(y_test, y_pred)}')
print('LOSS: ', log_loss(y_test, y_pred))
# Out:
# 0:	learn: 0.6521524	total: 98.7ms	remaining: 49.3s
# 1:	learn: 0.6221644	total: 179ms	remaining: 44.5s
# 2:	learn: 0.5901871	total: 264ms	remaining: 43.8s
# 3:	learn: 0.5612935	total: 353ms	remaining: 43.7s
# 4:	learn: 0.5361812	total: 447ms	remaining: 44.2s
# 5:	learn: 0.5064647	total: 535ms	remaining: 44.1s
# 6:	learn: 0.4866987	total: 618ms	remaining: 43.5s
# 7:	learn: 0.4629169	total: 703ms	remaining: 43.3s
# 8:	learn: 0.4470280	total: 783ms	remaining: 42.7s
# 9:	learn: 0.4305922	total: 869ms	remaining: 42.6s
# 10:	learn: 0.4117903	total: 960ms	remaining: 42.7s
# 11:	learn: 0.3961612	total: 1.04s	remaining: 42.3s
# 12:	learn: 0.3744721	total: 1.12s	remaining: 42.1s
# 13:	learn: 0.3610420	total: 1.21s	remaining: 42s
# 14:	learn: 0.3430945	total: 1.29s	remaining: 41.8s
# 15:	learn: 0.3320323	total: 1.38s	remaining: 41.8s
# 16:	learn: 0.3180835	total: 1.47s	remaining: 41.9s
# 17:	learn: 0.3058002	total: 1.55s	remaining: 41.6s
# 18:	learn: 0.2928724	total: 1.65s	remaining: 41.7s
# 19:	learn: 0.2833031	total: 1.73s	remaining: 41.5s
# 20:	learn: 0.2739037	total: 1.81s	remaining: 41.3s
# 21:	learn: 0.2654864	total: 1.91s	remaining: 41.6s
# 22:	learn: 0.2566772	total: 1.99s	remaining: 41.3s
# 23:	learn: 0.2494496	total: 2.07s	remaining: 41.1s
# 24:	learn: 0.2404145	total: 2.15s	remaining: 40.9s
# 25:	learn: 0.2351289	total: 2.24s	remaining: 40.8s
# 26:	learn: 0.2270758	total: 2.33s	remaining: 40.7s
# 27:	learn: 0.2229314	total: 2.41s	remaining: 40.6s
# 28:	learn: 0.2175383	total: 2.51s	remaining: 40.7s
# 29:	learn: 0.2122973	total: 2.59s	remaining: 40.5s
# 30:	learn: 0.2081120	total: 2.67s	remaining: 40.4s
# 31:	learn: 0.2031275	total: 2.76s	remaining: 40.3s
# 32:	learn: 0.2000988	total: 2.84s	remaining: 40.2s
# 33:	learn: 0.1933783	total: 2.93s	remaining: 40.1s
# 34:	learn: 0.1879424	total: 3.01s	remaining: 39.9s
# 35:	learn: 0.1847202	total: 3.08s	remaining: 39.8s
# 36:	learn: 0.1794859	total: 3.17s	remaining: 39.6s
# 37:	learn: 0.1751879	total: 3.25s	remaining: 39.6s
# 38:	learn: 0.1722770	total: 3.34s	remaining: 39.5s
# 39:	learn: 0.1700000	total: 3.43s	remaining: 39.5s
# 40:	learn: 0.1666471	total: 3.52s	remaining: 39.4s
# 41:	learn: 0.1638278	total: 3.6s	remaining: 39.3s
# 42:	learn: 0.1612647	total: 3.68s	remaining: 39.1s
# 43:	learn: 0.1581403	total: 3.76s	remaining: 39s
# 44:	learn: 0.1555582	total: 3.84s	remaining: 38.9s
# 45:	learn: 0.1532037	total: 3.93s	remaining: 38.8s
# 46:	learn: 0.1506839	total: 4.02s	remaining: 38.7s
# 47:	learn: 0.1482922	total: 4.09s	remaining: 38.6s
# 48:	learn: 0.1459206	total: 4.18s	remaining: 38.5s
# 49:	learn: 0.1430270	total: 4.27s	remaining: 38.4s
# 50:	learn: 0.1416777	total: 4.35s	remaining: 38.3s
# 51:	learn: 0.1406632	total: 4.43s	remaining: 38.2s
# 52:	learn: 0.1389845	total: 4.52s	remaining: 38.1s
# 53:	learn: 0.1383244	total: 4.61s	remaining: 38.1s
# 54:	learn: 0.1364839	total: 4.69s	remaining: 37.9s
# 55:	learn: 0.1357149	total: 4.77s	remaining: 37.8s
# 56:	learn: 0.1330653	total: 4.85s	remaining: 37.7s
# 57:	learn: 0.1329162	total: 4.94s	remaining: 37.7s
# 58:	learn: 0.1313538	total: 5.02s	remaining: 37.5s
# 59:	learn: 0.1304805	total: 5.1s	remaining: 37.4s
# 60:	learn: 0.1291188	total: 5.18s	remaining: 37.3s
# 61:	learn: 0.1277678	total: 5.27s	remaining: 37.2s
# 62:	learn: 0.1251858	total: 5.35s	remaining: 37.1s
# 63:	learn: 0.1232326	total: 5.44s	remaining: 37s
# 64:	learn: 0.1220801	total: 5.53s	remaining: 37s
# 65:	learn: 0.1219019	total: 5.61s	remaining: 36.9s
# 66:	learn: 0.1204150	total: 5.69s	remaining: 36.8s
# 67:	learn: 0.1191369	total: 5.77s	remaining: 36.6s
# 68:	learn: 0.1175096	total: 5.85s	remaining: 36.5s
# 69:	learn: 0.1166969	total: 5.94s	remaining: 36.5s
# 70:	learn: 0.1159142	total: 6.02s	remaining: 36.4s
# 71:	learn: 0.1138521	total: 6.09s	remaining: 36.2s
# 72:	learn: 0.1135909	total: 6.18s	remaining: 36.1s
# 73:	learn: 0.1123324	total: 6.26s	remaining: 36s
# 74:	learn: 0.1111320	total: 6.34s	remaining: 35.9s
# 75:	learn: 0.1103659	total: 6.43s	remaining: 35.9s
# 76:	learn: 0.1094092	total: 6.52s	remaining: 35.8s
# 77:	learn: 0.1086511	total: 6.6s	remaining: 35.7s
# 78:	learn: 0.1084123	total: 6.68s	remaining: 35.6s
# 79:	learn: 0.1072257	total: 6.77s	remaining: 35.5s
# 80:	learn: 0.1064542	total: 6.85s	remaining: 35.4s
# 81:	learn: 0.1050178	total: 6.93s	remaining: 35.3s
# 82:	learn: 0.1032884	total: 7.01s	remaining: 35.2s
# 83:	learn: 0.1028427	total: 7.09s	remaining: 35.1s
# 84:	learn: 0.1012332	total: 7.18s	remaining: 35.1s
# 85:	learn: 0.1007606	total: 7.26s	remaining: 35s
# 86:	learn: 0.1000942	total: 7.35s	remaining: 34.9s
# 87:	learn: 0.0989214	total: 7.43s	remaining: 34.8s
# 88:	learn: 0.0982388	total: 7.51s	remaining: 34.7s
# 89:	learn: 0.0978104	total: 7.6s	remaining: 34.6s
# 90:	learn: 0.0976545	total: 7.68s	remaining: 34.5s
# 91:	learn: 0.0966276	total: 7.77s	remaining: 34.4s
# 92:	learn: 0.0964406	total: 7.85s	remaining: 34.3s
# 93:	learn: 0.0950807	total: 7.93s	remaining: 34.3s
# 94:	learn: 0.0937412	total: 8.01s	remaining: 34.1s
# 95:	learn: 0.0926466	total: 8.09s	remaining: 34s
# 96:	learn: 0.0917582	total: 8.18s	remaining: 34s
# 97:	learn: 0.0906404	total: 8.27s	remaining: 33.9s
# 98:	learn: 0.0897225	total: 8.35s	remaining: 33.8s
# 99:	learn: 0.0896204	total: 8.43s	remaining: 33.7s
# 100:	learn: 0.0884472	total: 8.51s	remaining: 33.6s
# 101:	learn: 0.0883057	total: 8.6s	remaining: 33.6s
# 102:	learn: 0.0875788	total: 8.69s	remaining: 33.5s
# 103:	learn: 0.0874918	total: 8.78s	remaining: 33.4s
# 104:	learn: 0.0865848	total: 8.85s	remaining: 33.3s
# 105:	learn: 0.0862638	total: 8.93s	remaining: 33.2s
# 106:	learn: 0.0856006	total: 9.01s	remaining: 33.1s
# 107:	learn: 0.0847544	total: 9.11s	remaining: 33.1s
# 108:	learn: 0.0846795	total: 9.26s	remaining: 33.2s
# 109:	learn: 0.0838695	total: 9.42s	remaining: 33.4s
# 110:	learn: 0.0831670	total: 9.58s	remaining: 33.6s
# 111:	learn: 0.0829375	total: 9.73s	remaining: 33.7s
# 112:	learn: 0.0816644	total: 9.89s	remaining: 33.9s
# 113:	learn: 0.0807708	total: 10s	remaining: 34s
# 114:	learn: 0.0799518	total: 10.2s	remaining: 34.2s
# 115:	learn: 0.0786143	total: 10.4s	remaining: 34.3s
# 116:	learn: 0.0779435	total: 10.5s	remaining: 34.5s
# 117:	learn: 0.0778407	total: 10.7s	remaining: 34.6s
# 118:	learn: 0.0764956	total: 10.8s	remaining: 34.7s
# 119:	learn: 0.0759018	total: 11s	remaining: 34.8s
# 120:	learn: 0.0752601	total: 11.2s	remaining: 34.9s
# 121:	learn: 0.0745685	total: 11.3s	remaining: 35s
# 122:	learn: 0.0736135	total: 11.5s	remaining: 35.1s
# 123:	learn: 0.0733233	total: 11.6s	remaining: 35.3s
# 124:	learn: 0.0727756	total: 11.8s	remaining: 35.4s
# 125:	learn: 0.0723707	total: 12s	remaining: 35.5s
# 126:	learn: 0.0721764	total: 12.1s	remaining: 35.5s
# 127:	learn: 0.0716265	total: 12.3s	remaining: 35.6s
# 128:	learn: 0.0708698	total: 12.4s	remaining: 35.7s
# 129:	learn: 0.0704583	total: 12.6s	remaining: 35.7s
# 130:	learn: 0.0698094	total: 12.7s	remaining: 35.8s
# 131:	learn: 0.0691427	total: 12.9s	remaining: 35.9s
# 132:	learn: 0.0690391	total: 13s	remaining: 35.9s
# 133:	learn: 0.0682391	total: 13.2s	remaining: 36s
# 134:	learn: 0.0681418	total: 13.3s	remaining: 36.1s
# 135:	learn: 0.0669715	total: 13.4s	remaining: 35.9s
# 136:	learn: 0.0665369	total: 13.5s	remaining: 35.8s
# 137:	learn: 0.0663584	total: 13.6s	remaining: 35.7s
# 138:	learn: 0.0653933	total: 13.7s	remaining: 35.5s
# 139:	learn: 0.0649171	total: 13.8s	remaining: 35.4s
# 140:	learn: 0.0637489	total: 13.8s	remaining: 35.3s
# 141:	learn: 0.0631705	total: 13.9s	remaining: 35.1s
# 142:	learn: 0.0624441	total: 14s	remaining: 35s
# 143:	learn: 0.0619913	total: 14.1s	remaining: 34.8s
# 144:	learn: 0.0619164	total: 14.2s	remaining: 34.7s
# 145:	learn: 0.0613380	total: 14.3s	remaining: 34.6s
# 146:	learn: 0.0608846	total: 14.3s	remaining: 34.4s
# 147:	learn: 0.0599181	total: 14.4s	remaining: 34.3s
# 148:	learn: 0.0593242	total: 14.5s	remaining: 34.2s
# 149:	learn: 0.0591230	total: 14.6s	remaining: 34s
# 150:	learn: 0.0587986	total: 14.7s	remaining: 33.9s
# 151:	learn: 0.0581825	total: 14.8s	remaining: 33.8s
# 152:	learn: 0.0576394	total: 14.8s	remaining: 33.7s
# 153:	learn: 0.0569870	total: 14.9s	remaining: 33.5s
# 154:	learn: 0.0562983	total: 15s	remaining: 33.4s
# 155:	learn: 0.0556502	total: 15.1s	remaining: 33.3s
# 156:	learn: 0.0545319	total: 15.2s	remaining: 33.2s
# 157:	learn: 0.0544661	total: 15.3s	remaining: 33s
# 158:	learn: 0.0544032	total: 15.3s	remaining: 32.9s
# 159:	learn: 0.0538812	total: 15.4s	remaining: 32.8s
# 160:	learn: 0.0533433	total: 15.5s	remaining: 32.6s
# 161:	learn: 0.0529299	total: 15.6s	remaining: 32.5s
# 162:	learn: 0.0527635	total: 15.7s	remaining: 32.4s
# 163:	learn: 0.0525877	total: 15.8s	remaining: 32.3s
# 164:	learn: 0.0524731	total: 15.8s	remaining: 32.2s
# 165:	learn: 0.0519500	total: 15.9s	remaining: 32s
# 166:	learn: 0.0518143	total: 16s	remaining: 31.9s
# 167:	learn: 0.0508475	total: 16.1s	remaining: 31.8s
# 168:	learn: 0.0507876	total: 16.2s	remaining: 31.7s
# 169:	learn: 0.0507274	total: 16.2s	remaining: 31.5s
# 170:	learn: 0.0498116	total: 16.3s	remaining: 31.4s
# 171:	learn: 0.0490898	total: 16.4s	remaining: 31.3s
# 172:	learn: 0.0488753	total: 16.5s	remaining: 31.2s
# 173:	learn: 0.0488276	total: 16.6s	remaining: 31.1s
# 174:	learn: 0.0482881	total: 16.7s	remaining: 30.9s
# 175:	learn: 0.0475029	total: 16.8s	remaining: 30.8s
# 176:	learn: 0.0470534	total: 16.8s	remaining: 30.7s
# 177:	learn: 0.0469425	total: 16.9s	remaining: 30.6s
# 178:	learn: 0.0468563	total: 17s	remaining: 30.5s
# 179:	learn: 0.0465339	total: 17.1s	remaining: 30.4s
# 180:	learn: 0.0461056	total: 17.2s	remaining: 30.2s
# 181:	learn: 0.0460552	total: 17.2s	remaining: 30.1s
# 182:	learn: 0.0454862	total: 17.3s	remaining: 30s
# 183:	learn: 0.0449863	total: 17.4s	remaining: 29.9s
# 184:	learn: 0.0449284	total: 17.5s	remaining: 29.8s
# 185:	learn: 0.0446289	total: 17.6s	remaining: 29.7s
# 186:	learn: 0.0442413	total: 17.7s	remaining: 29.6s
# 187:	learn: 0.0437021	total: 17.8s	remaining: 29.5s
# 188:	learn: 0.0436634	total: 17.8s	remaining: 29.4s
# 189:	learn: 0.0436168	total: 17.9s	remaining: 29.2s
# 190:	learn: 0.0435721	total: 18s	remaining: 29.1s
# 191:	learn: 0.0433961	total: 18.1s	remaining: 29s
# 192:	learn: 0.0428722	total: 18.2s	remaining: 28.9s
# 193:	learn: 0.0425323	total: 18.3s	remaining: 28.8s
# 194:	learn: 0.0420788	total: 18.3s	remaining: 28.7s
# 195:	learn: 0.0420409	total: 18.4s	remaining: 28.6s
# 196:	learn: 0.0418828	total: 18.5s	remaining: 28.4s
# 197:	learn: 0.0414997	total: 18.6s	remaining: 28.4s
# 198:	learn: 0.0405517	total: 18.7s	remaining: 28.2s
# 199:	learn: 0.0405197	total: 18.8s	remaining: 28.1s
# 200:	learn: 0.0399763	total: 18.8s	remaining: 28s
# 201:	learn: 0.0395355	total: 18.9s	remaining: 27.9s
# 202:	learn: 0.0394243	total: 19s	remaining: 27.8s
# 203:	learn: 0.0388096	total: 19.1s	remaining: 27.7s
# 204:	learn: 0.0383554	total: 19.2s	remaining: 27.6s
# 205:	learn: 0.0379536	total: 19.3s	remaining: 27.5s
# 206:	learn: 0.0373909	total: 19.3s	remaining: 27.4s
# 207:	learn: 0.0369474	total: 19.4s	remaining: 27.3s
# 208:	learn: 0.0365761	total: 19.5s	remaining: 27.2s
# 209:	learn: 0.0361820	total: 19.6s	remaining: 27s
# 210:	learn: 0.0354325	total: 19.7s	remaining: 26.9s
# 211:	learn: 0.0351666	total: 19.7s	remaining: 26.8s
# 212:	learn: 0.0345443	total: 19.8s	remaining: 26.7s
# 213:	learn: 0.0344522	total: 19.9s	remaining: 26.6s
# 214:	learn: 0.0343647	total: 20s	remaining: 26.5s
# 215:	learn: 0.0340264	total: 20.1s	remaining: 26.4s
# 216:	learn: 0.0339327	total: 20.2s	remaining: 26.3s
# 217:	learn: 0.0337756	total: 20.3s	remaining: 26.2s
# 218:	learn: 0.0333420	total: 20.3s	remaining: 26.1s
# 219:	learn: 0.0330437	total: 20.4s	remaining: 26s
# 220:	learn: 0.0330106	total: 20.5s	remaining: 25.9s
# 221:	learn: 0.0329802	total: 20.6s	remaining: 25.8s
# 222:	learn: 0.0326019	total: 20.7s	remaining: 25.7s
# 223:	learn: 0.0324991	total: 20.7s	remaining: 25.6s
# 224:	learn: 0.0324740	total: 20.8s	remaining: 25.5s
# 225:	learn: 0.0324455	total: 20.9s	remaining: 25.4s
# 226:	learn: 0.0321991	total: 21s	remaining: 25.3s
# 227:	learn: 0.0317058	total: 21.1s	remaining: 25.2s
# 228:	learn: 0.0316738	total: 21.2s	remaining: 25.1s
# 229:	learn: 0.0310269	total: 21.3s	remaining: 24.9s
# 230:	learn: 0.0306875	total: 21.3s	remaining: 24.8s
# 231:	learn: 0.0303558	total: 21.4s	remaining: 24.7s
# 232:	learn: 0.0302716	total: 21.5s	remaining: 24.6s
# 233:	learn: 0.0302047	total: 21.6s	remaining: 24.5s
# 234:	learn: 0.0298020	total: 21.7s	remaining: 24.4s
# 235:	learn: 0.0295520	total: 21.7s	remaining: 24.3s
# 236:	learn: 0.0294619	total: 21.8s	remaining: 24.2s
# 237:	learn: 0.0291596	total: 21.9s	remaining: 24.1s
# 238:	learn: 0.0290956	total: 22s	remaining: 24s
# 239:	learn: 0.0287469	total: 22.1s	remaining: 23.9s
# 240:	learn: 0.0286858	total: 22.2s	remaining: 23.8s
# 241:	learn: 0.0283277	total: 22.2s	remaining: 23.7s
# 242:	learn: 0.0280838	total: 22.3s	remaining: 23.6s
# 243:	learn: 0.0278511	total: 22.4s	remaining: 23.5s
# 244:	learn: 0.0277852	total: 22.5s	remaining: 23.4s
# 245:	learn: 0.0275069	total: 22.6s	remaining: 23.3s
# 246:	learn: 0.0273309	total: 22.7s	remaining: 23.2s
# 247:	learn: 0.0271386	total: 22.7s	remaining: 23.1s
# 248:	learn: 0.0270778	total: 22.8s	remaining: 23s
# 249:	learn: 0.0269999	total: 22.9s	remaining: 22.9s
# 250:	learn: 0.0269182	total: 23s	remaining: 22.8s
# 251:	learn: 0.0269013	total: 23.1s	remaining: 22.7s
# 252:	learn: 0.0264500	total: 23.2s	remaining: 22.6s
# 253:	learn: 0.0263938	total: 23.3s	remaining: 22.5s
# 254:	learn: 0.0261607	total: 23.4s	remaining: 22.5s
# 255:	learn: 0.0258863	total: 23.6s	remaining: 22.5s
# 256:	learn: 0.0258218	total: 23.7s	remaining: 22.4s
# 257:	learn: 0.0256023	total: 23.9s	remaining: 22.4s
# 258:	learn: 0.0254165	total: 24s	remaining: 22.3s
# 259:	learn: 0.0251977	total: 24.1s	remaining: 22.3s
# 260:	learn: 0.0251283	total: 24.3s	remaining: 22.2s
# 261:	learn: 0.0249290	total: 24.4s	remaining: 22.2s
# 262:	learn: 0.0248307	total: 24.6s	remaining: 22.2s
# 263:	learn: 0.0247656	total: 24.7s	remaining: 22.1s
# 264:	learn: 0.0247205	total: 24.9s	remaining: 22.1s
# 265:	learn: 0.0244691	total: 25.1s	remaining: 22.1s
# 266:	learn: 0.0244326	total: 25.2s	remaining: 22s
# 267:	learn: 0.0240612	total: 25.3s	remaining: 21.9s
# 268:	learn: 0.0237974	total: 25.5s	remaining: 21.9s
# 269:	learn: 0.0237802	total: 25.6s	remaining: 21.8s
# 270:	learn: 0.0237660	total: 25.8s	remaining: 21.8s
# 271:	learn: 0.0237219	total: 25.9s	remaining: 21.7s
# 272:	learn: 0.0237071	total: 26.1s	remaining: 21.7s
# 273:	learn: 0.0236922	total: 26.3s	remaining: 21.7s
# 274:	learn: 0.0234948	total: 26.4s	remaining: 21.6s
# 275:	learn: 0.0231889	total: 26.6s	remaining: 21.6s
# 276:	learn: 0.0229683	total: 26.8s	remaining: 21.5s
# 277:	learn: 0.0227873	total: 26.9s	remaining: 21.5s
# 278:	learn: 0.0227439	total: 27.1s	remaining: 21.4s
# 279:	learn: 0.0225221	total: 27.2s	remaining: 21.4s
# 280:	learn: 0.0225084	total: 27.4s	remaining: 21.3s
# 281:	learn: 0.0223358	total: 27.5s	remaining: 21.3s
# 282:	learn: 0.0222882	total: 27.7s	remaining: 21.2s
# 283:	learn: 0.0222337	total: 27.7s	remaining: 21.1s
# 284:	learn: 0.0222171	total: 27.8s	remaining: 21s
# 285:	learn: 0.0219758	total: 28s	remaining: 20.9s
# 286:	learn: 0.0217977	total: 28.1s	remaining: 20.8s
# 287:	learn: 0.0215485	total: 28.1s	remaining: 20.7s
# 288:	learn: 0.0213553	total: 28.2s	remaining: 20.6s
# 289:	learn: 0.0213022	total: 28.3s	remaining: 20.5s
# 290:	learn: 0.0212618	total: 28.4s	remaining: 20.4s
# 291:	learn: 0.0210262	total: 28.5s	remaining: 20.3s
# 292:	learn: 0.0209846	total: 28.6s	remaining: 20.2s
# 293:	learn: 0.0209487	total: 28.6s	remaining: 20.1s
# 294:	learn: 0.0209230	total: 28.7s	remaining: 20s
# 295:	learn: 0.0209107	total: 28.8s	remaining: 19.9s
# 296:	learn: 0.0208705	total: 28.9s	remaining: 19.7s
# 297:	learn: 0.0208583	total: 29s	remaining: 19.6s
# 298:	learn: 0.0206147	total: 29.1s	remaining: 19.5s
# 299:	learn: 0.0204700	total: 29.1s	remaining: 19.4s
# 300:	learn: 0.0201181	total: 29.2s	remaining: 19.3s
# 301:	learn: 0.0200930	total: 29.3s	remaining: 19.2s
# 302:	learn: 0.0198725	total: 29.4s	remaining: 19.1s
# 303:	learn: 0.0198296	total: 29.5s	remaining: 19s
# 304:	learn: 0.0198025	total: 29.6s	remaining: 18.9s
# 305:	learn: 0.0197777	total: 29.7s	remaining: 18.8s
# 306:	learn: 0.0197548	total: 29.7s	remaining: 18.7s
# 307:	learn: 0.0197311	total: 29.8s	remaining: 18.6s
# 308:	learn: 0.0197201	total: 29.9s	remaining: 18.5s
# 309:	learn: 0.0196898	total: 30s	remaining: 18.4s
# 310:	learn: 0.0196679	total: 30.1s	remaining: 18.3s
# 311:	learn: 0.0195273	total: 30.1s	remaining: 18.2s
# 312:	learn: 0.0193317	total: 30.2s	remaining: 18.1s
# 313:	learn: 0.0191050	total: 30.3s	remaining: 18s
# 314:	learn: 0.0190764	total: 30.4s	remaining: 17.9s
# 315:	learn: 0.0189244	total: 30.5s	remaining: 17.7s
# 316:	learn: 0.0188938	total: 30.6s	remaining: 17.6s
# 317:	learn: 0.0187122	total: 30.6s	remaining: 17.5s
# 318:	learn: 0.0187032	total: 30.7s	remaining: 17.4s
# 319:	learn: 0.0186585	total: 30.8s	remaining: 17.3s
# 320:	learn: 0.0184659	total: 30.9s	remaining: 17.2s
# 321:	learn: 0.0183930	total: 31s	remaining: 17.1s
# 322:	learn: 0.0181980	total: 31.1s	remaining: 17s
# 323:	learn: 0.0180752	total: 31.2s	remaining: 16.9s
# 324:	learn: 0.0180546	total: 31.2s	remaining: 16.8s
# 325:	learn: 0.0180449	total: 31.3s	remaining: 16.7s
# 326:	learn: 0.0180356	total: 31.4s	remaining: 16.6s
# 327:	learn: 0.0178614	total: 31.5s	remaining: 16.5s
# 328:	learn: 0.0178507	total: 31.6s	remaining: 16.4s
# 329:	learn: 0.0176708	total: 31.7s	remaining: 16.3s
# 330:	learn: 0.0176105	total: 31.7s	remaining: 16.2s
# 331:	learn: 0.0175819	total: 31.8s	remaining: 16.1s
# 332:	learn: 0.0174403	total: 31.9s	remaining: 16s
# 333:	learn: 0.0174232	total: 32s	remaining: 15.9s
# 334:	learn: 0.0172054	total: 32.1s	remaining: 15.8s
# 335:	learn: 0.0171941	total: 32.2s	remaining: 15.7s
# 336:	learn: 0.0169996	total: 32.2s	remaining: 15.6s
# 337:	learn: 0.0169397	total: 32.3s	remaining: 15.5s
# 338:	learn: 0.0169132	total: 32.4s	remaining: 15.4s
# 339:	learn: 0.0168958	total: 32.5s	remaining: 15.3s
# 340:	learn: 0.0167226	total: 32.6s	remaining: 15.2s
# 341:	learn: 0.0166593	total: 32.6s	remaining: 15.1s
# 342:	learn: 0.0165353	total: 32.7s	remaining: 15s
# 343:	learn: 0.0165178	total: 32.8s	remaining: 14.9s
# 344:	learn: 0.0165009	total: 32.9s	remaining: 14.8s
# 345:	learn: 0.0164933	total: 33s	remaining: 14.7s
# 346:	learn: 0.0163104	total: 33.1s	remaining: 14.6s
# 347:	learn: 0.0162914	total: 33.2s	remaining: 14.5s
# 348:	learn: 0.0161988	total: 33.2s	remaining: 14.4s
# 349:	learn: 0.0161891	total: 33.3s	remaining: 14.3s
# 350:	learn: 0.0161731	total: 33.4s	remaining: 14.2s
# 351:	learn: 0.0159122	total: 33.5s	remaining: 14.1s
# 352:	learn: 0.0158353	total: 33.6s	remaining: 14s
# 353:	learn: 0.0158209	total: 33.6s	remaining: 13.9s
# 354:	learn: 0.0158064	total: 33.7s	remaining: 13.8s
# 355:	learn: 0.0157899	total: 33.8s	remaining: 13.7s
# 356:	learn: 0.0157759	total: 33.9s	remaining: 13.6s
# 357:	learn: 0.0157289	total: 34s	remaining: 13.5s
# 358:	learn: 0.0157193	total: 34.1s	remaining: 13.4s
# 359:	learn: 0.0157131	total: 34.2s	remaining: 13.3s
# 360:	learn: 0.0154423	total: 34.2s	remaining: 13.2s
# 361:	learn: 0.0153493	total: 34.3s	remaining: 13.1s
# 362:	learn: 0.0151996	total: 34.4s	remaining: 13s
# 363:	learn: 0.0151950	total: 34.5s	remaining: 12.9s
# 364:	learn: 0.0149282	total: 34.6s	remaining: 12.8s
# 365:	learn: 0.0149133	total: 34.6s	remaining: 12.7s
# 366:	learn: 0.0148993	total: 34.7s	remaining: 12.6s
# 367:	learn: 0.0148848	total: 34.8s	remaining: 12.5s
# 368:	learn: 0.0148766	total: 34.9s	remaining: 12.4s
# 369:	learn: 0.0148631	total: 35s	remaining: 12.3s
# 370:	learn: 0.0146154	total: 35.1s	remaining: 12.2s
# 371:	learn: 0.0145095	total: 35.1s	remaining: 12.1s
# 372:	learn: 0.0143948	total: 35.2s	remaining: 12s
# 373:	learn: 0.0143215	total: 35.3s	remaining: 11.9s
# 374:	learn: 0.0143164	total: 35.4s	remaining: 11.8s
# 375:	learn: 0.0142909	total: 35.5s	remaining: 11.7s
# 376:	learn: 0.0142854	total: 35.6s	remaining: 11.6s
# 377:	learn: 0.0141967	total: 35.6s	remaining: 11.5s
# 378:	learn: 0.0141909	total: 35.7s	remaining: 11.4s
# 379:	learn: 0.0140461	total: 35.8s	remaining: 11.3s
# 380:	learn: 0.0139047	total: 35.9s	remaining: 11.2s
# 381:	learn: 0.0137282	total: 36s	remaining: 11.1s
# 382:	learn: 0.0136388	total: 36.1s	remaining: 11s
# 383:	learn: 0.0136318	total: 36.1s	remaining: 10.9s
# 384:	learn: 0.0136153	total: 36.2s	remaining: 10.8s
# 385:	learn: 0.0135397	total: 36.3s	remaining: 10.7s
# 386:	learn: 0.0135336	total: 36.4s	remaining: 10.6s
# 387:	learn: 0.0135279	total: 36.5s	remaining: 10.5s
# 388:	learn: 0.0134009	total: 36.6s	remaining: 10.4s
# 389:	learn: 0.0132106	total: 36.6s	remaining: 10.3s
# 390:	learn: 0.0130137	total: 36.7s	remaining: 10.2s
# 391:	learn: 0.0129229	total: 36.8s	remaining: 10.1s
# 392:	learn: 0.0128399	total: 36.9s	remaining: 10s
# 393:	learn: 0.0127455	total: 37s	remaining: 9.95s
# 394:	learn: 0.0127097	total: 37.1s	remaining: 9.85s
# 395:	learn: 0.0126953	total: 37.1s	remaining: 9.75s
# 396:	learn: 0.0126057	total: 37.2s	remaining: 9.66s
# 397:	learn: 0.0125046	total: 37.3s	remaining: 9.56s
# 398:	learn: 0.0124197	total: 37.4s	remaining: 9.47s
# 399:	learn: 0.0124049	total: 37.5s	remaining: 9.37s
# 400:	learn: 0.0123657	total: 37.6s	remaining: 9.29s
# 401:	learn: 0.0122972	total: 37.8s	remaining: 9.21s
# 402:	learn: 0.0122861	total: 37.9s	remaining: 9.13s
# 403:	learn: 0.0122699	total: 38.1s	remaining: 9.05s
# 404:	learn: 0.0121704	total: 38.3s	remaining: 8.98s
# 405:	learn: 0.0119727	total: 38.4s	remaining: 8.9s
# 406:	learn: 0.0119109	total: 38.6s	remaining: 8.82s
# 407:	learn: 0.0118367	total: 38.7s	remaining: 8.74s
# 408:	learn: 0.0118266	total: 38.9s	remaining: 8.65s
# 409:	learn: 0.0118223	total: 39.1s	remaining: 8.58s
# 410:	learn: 0.0117162	total: 39.2s	remaining: 8.49s
# 411:	learn: 0.0117103	total: 39.4s	remaining: 8.41s
# 412:	learn: 0.0116037	total: 39.6s	remaining: 8.33s
# 413:	learn: 0.0115362	total: 39.7s	remaining: 8.25s
# 414:	learn: 0.0114431	total: 39.9s	remaining: 8.17s
# 415:	learn: 0.0114283	total: 40s	remaining: 8.09s
# 416:	learn: 0.0114166	total: 40.2s	remaining: 8s
# 417:	learn: 0.0113984	total: 40.4s	remaining: 7.92s
# 418:	learn: 0.0113225	total: 40.5s	remaining: 7.83s
# 419:	learn: 0.0112655	total: 40.6s	remaining: 7.74s
# 420:	learn: 0.0112239	total: 40.8s	remaining: 7.66s
# 421:	learn: 0.0112200	total: 41s	remaining: 7.57s
# 422:	learn: 0.0112025	total: 41.1s	remaining: 7.48s
# 423:	learn: 0.0111892	total: 41.3s	remaining: 7.4s
# 424:	learn: 0.0111730	total: 41.4s	remaining: 7.31s
# 425:	learn: 0.0111690	total: 41.6s	remaining: 7.22s
# 426:	learn: 0.0111526	total: 41.7s	remaining: 7.13s
# 427:	learn: 0.0111373	total: 41.8s	remaining: 7.04s
# 428:	learn: 0.0110555	total: 41.9s	remaining: 6.94s
# 429:	learn: 0.0109193	total: 42s	remaining: 6.84s
# 430:	learn: 0.0109146	total: 42.1s	remaining: 6.74s
# 431:	learn: 0.0108229	total: 42.2s	remaining: 6.64s
# 432:	learn: 0.0108048	total: 42.2s	remaining: 6.54s
# 433:	learn: 0.0107202	total: 42.4s	remaining: 6.44s
# 434:	learn: 0.0107093	total: 42.4s	remaining: 6.34s
# 435:	learn: 0.0106404	total: 42.5s	remaining: 6.24s
# 436:	learn: 0.0105613	total: 42.6s	remaining: 6.14s
# 437:	learn: 0.0105393	total: 42.7s	remaining: 6.04s
# 438:	learn: 0.0105300	total: 42.8s	remaining: 5.94s
# 439:	learn: 0.0105260	total: 42.8s	remaining: 5.84s
# 440:	learn: 0.0105154	total: 42.9s	remaining: 5.74s
# 441:	learn: 0.0105050	total: 43s	remaining: 5.64s
# 442:	learn: 0.0105019	total: 43.1s	remaining: 5.54s
# 443:	learn: 0.0104904	total: 43.2s	remaining: 5.45s
# 444:	learn: 0.0104868	total: 43.3s	remaining: 5.35s
# 445:	learn: 0.0104723	total: 43.3s	remaining: 5.25s
# 446:	learn: 0.0104693	total: 43.4s	remaining: 5.15s
# 447:	learn: 0.0104553	total: 43.5s	remaining: 5.05s
# 448:	learn: 0.0104519	total: 43.6s	remaining: 4.95s
# 449:	learn: 0.0104387	total: 43.7s	remaining: 4.85s
# 450:	learn: 0.0103631	total: 43.8s	remaining: 4.75s
# 451:	learn: 0.0103280	total: 43.8s	remaining: 4.66s
# 452:	learn: 0.0103281	total: 43.9s	remaining: 4.56s
# 453:	learn: 0.0103185	total: 44s	remaining: 4.46s
# 454:	learn: 0.0102535	total: 44.1s	remaining: 4.36s
# 455:	learn: 0.0101129	total: 44.2s	remaining: 4.26s
# 456:	learn: 0.0100363	total: 44.2s	remaining: 4.16s
# 457:	learn: 0.0100254	total: 44.3s	remaining: 4.07s
# 458:	learn: 0.0099328	total: 44.4s	remaining: 3.97s
# 459:	learn: 0.0098462	total: 44.5s	remaining: 3.87s
# 460:	learn: 0.0098376	total: 44.6s	remaining: 3.77s
# 461:	learn: 0.0098293	total: 44.7s	remaining: 3.67s
# 462:	learn: 0.0098293	total: 44.8s	remaining: 3.58s
# 463:	learn: 0.0097897	total: 44.8s	remaining: 3.48s
# 464:	learn: 0.0097815	total: 44.9s	remaining: 3.38s
# 465:	learn: 0.0097744	total: 45s	remaining: 3.28s
# 466:	learn: 0.0097671	total: 45.1s	remaining: 3.19s
# 467:	learn: 0.0097671	total: 45.2s	remaining: 3.09s
# 468:	learn: 0.0097597	total: 45.3s	remaining: 2.99s
# 469:	learn: 0.0097551	total: 45.3s	remaining: 2.89s
# 470:	learn: 0.0097482	total: 45.4s	remaining: 2.8s
# 471:	learn: 0.0097388	total: 45.5s	remaining: 2.7s
# 472:	learn: 0.0096517	total: 45.6s	remaining: 2.6s
# 473:	learn: 0.0096271	total: 45.7s	remaining: 2.5s
# 474:	learn: 0.0096213	total: 45.8s	remaining: 2.41s
# 475:	learn: 0.0096145	total: 45.8s	remaining: 2.31s
# 476:	learn: 0.0096112	total: 45.9s	remaining: 2.21s
# 477:	learn: 0.0095135	total: 46s	remaining: 2.12s
# 478:	learn: 0.0095108	total: 46.1s	remaining: 2.02s
# 479:	learn: 0.0095047	total: 46.2s	remaining: 1.92s
# 480:	learn: 0.0095047	total: 46.3s	remaining: 1.83s
# 481:	learn: 0.0094958	total: 46.3s	remaining: 1.73s
# 482:	learn: 0.0094930	total: 46.4s	remaining: 1.63s
# 483:	learn: 0.0094644	total: 46.5s	remaining: 1.54s
# 484:	learn: 0.0093789	total: 46.6s	remaining: 1.44s
# 485:	learn: 0.0093762	total: 46.7s	remaining: 1.34s
# 486:	learn: 0.0093734	total: 46.8s	remaining: 1.25s
# 487:	learn: 0.0093734	total: 46.8s	remaining: 1.15s
# 488:	learn: 0.0093327	total: 46.9s	remaining: 1.05s
# 489:	learn: 0.0092544	total: 47s	remaining: 959ms
# 490:	learn: 0.0091994	total: 47.1s	remaining: 863ms
# 491:	learn: 0.0091993	total: 47.2s	remaining: 767ms
# 492:	learn: 0.0091968	total: 47.3s	remaining: 671ms
# 493:	learn: 0.0091881	total: 47.3s	remaining: 575ms
# 494:	learn: 0.0091008	total: 47.4s	remaining: 479ms
# 495:	learn: 0.0089861	total: 47.5s	remaining: 383ms
# 496:	learn: 0.0089746	total: 47.6s	remaining: 287ms
# 497:	learn: 0.0088393	total: 47.7s	remaining: 191ms
# 498:	learn: 0.0088369	total: 47.8s	remaining: 95.7ms
# 499:	learn: 0.0088343	total: 47.8s	remaining: 0us
# Accuracy Score: 0.9733333333333334
# LOSS:  0.9611640903764577

# %%
predictions = model.predict(tess_)
sub_file = pd.DataFrame({'ID': test_data_S1S2.ID, 'Target': predictions})
sub_file.to_csv('iran.csv', index = False)

# %% [markdown]
# # <font color="brown"> Final model

# %%
# Load best models
model1 = pd.read_csv('afghanistan.csv')
model2 = pd.read_csv('sudan.csv')
model3 = pd.read_csv('iran.csv')

# %%
Final_model = pd.concat([model3, model2, model1], axis=0)
Final_model.to_csv('Final_model.csv', index = False)
